# %% [markdown]
# # Component: West Antarctic Ice Sheet (WAIS)
#
# This notebook projects the WAIS contribution to global mean sea level
# (GMSL) using a two-scenario mixture (code identifier: `A4_SCENARIOS`)
# rather than a data-driven rate–temperature regression. The
# mixture represents continued stable and unstable discharge.
#
# ---
#
# ## Scenario Framework
#
# | Scenario | $P$ | Range (mm, 2100) | Distribution | Physics |
# |----------|-----|-------------------|--------------|---------|
# | **S1**: Status quo | 0.10 | median 90, [61, 118] (90% CI) | Direct posterior (quadratic fit to IMBIE) | No MISI |
# | **S2**: Fast WAIS (MISI + MICI) | 0.90 | 130–1300 (5th/95th) | Skew-normal in log-space, $\alpha=3$ | MISI, with or without ice-cliff cascade |
#
# The combined distribution is SSP-independent (see below).
#
# ---
#
# ## S1: Status quo ($P = 0.10$)
#
# WAIS continues to lose mass consistent with observed trends. The distribution
# is sampled directly from a Bayesian quadratic-in-time fit to the
# observed IMBIE WAIS record (1992–2020, §3 below):
#
# $$H(t) = 0.5a t^2 + vt + H_0 \qquad (t \text{ in years since 2000})$$
#
# S1's 2100 endpoint and its trajectory before 2100 are both draws from
# this fitted $(a, v, H_0)$ posterior, spliced onto the observed record at the
# anchor year for continuity.
#
# The chosen 10% weight reflects growing evidence that WAIS may be in a configuration that
# allows for the marine ice sheet instability to drive rapid ice loss (Joughin et
# al. 2014), with ocean thermal forcing sufficient for retreat regardless of
# emissions pathway in the 21st century (Naughten et al. 2023), and present-day forcing
# sufficient to deglaciate large WAIS sectors (van den Akker et al. 2025). We provide
# a sensitivity analysis to the parameter choices.
#
# ---
#
# ## S2: Fast WAIS — MISI + MICI ($P = 0.90$; 130–1300 mm; $\alpha = 3$)
#
# The second scenario represents the ``deep uncertainty'' in WAIS's contribution
# to GMSL, where MISI drives accelerating grounding-line retreat on retrograde beds,
# possibly compounded by marine ice cliff instability (MICI; Bassis & Walker
# 2012; DeConto & Pollard 2016).
#
# **Lower bound (130 mm)** is pinned to the 99th percentile of
# S1_status_quo's endpoint distribution (§3 above): MISI-triggered outcomes
# are expected to exceed anything a continued no-instability trend can
# produce, so S2's floor is set just above S1's upper tail.
#
# **Upper bound (1300 mm)** is pinned to the IPCC AR6 low-confidence
# Antarctic ice sheet 95th percentile under SSP5-8.5 (Fox-Kemper et al.
# 2021: 1309 mm, rounded), cross-checked against: the Amundsen Sea
# Embayment's ice volume above flotation plus spillover to neighboring
# basins ($V_{af} \approx 1100$ mm; Morlighem et al. 2020); Bamber et al.
# (2019)'s WAIS 95th percentile at +5°C (930 mm); DeConto & Pollard (2016)'s
# most aggressive MICI projection (≈640–1140 mm total Antarctic); and the
# kinematic constraint that reaching 1300 mm by 2100 requires a sustained rate
# roughly 5× the peak rate found under present-day forcing by van den Akker et al.
# (2025) — consistent with AR6's own "low confidence" framing.
#
# **Skewness** ($\alpha = 3$): S2's endpoint distribution is right-skewed,
# reflecting the grounding-line flux nonlinearity that amplifies uncertainty
# toward greater ice loss once MISI is triggered (Robel et al. 2019).
# $\alpha$ only reshapes the distribution between its fixed 5th/95th
# percentile bounds (130–1300 mm, set independently of $\alpha$), and
# sweeping $\alpha$ from 0 to 4 shifts the mixture median by at most 0.13 m
# (§6) — the qualitative result (a wide, right-skewed tail) does not depend
# on its precise value.
#
# MISI is the most physically supported instability mechanism and is
# arguably already initiated (Joughin et al. 2014; Rignot et al. 2026),
# consistent with IPCC AR6 medium-confidence framing. The 90% weight
# reflects this as the baseline expectation for WAIS evolution.
#
# ---
#
# ## S2 endpoint distribution
#
# S2 samples are drawn from a skew-normal distribution in log-space: this
# keeps $H_{2100} > 0$ without truncation, matches the multiplicative
# structure of the dominant uncertainties (bed geometry, basal friction,
# ocean forcing, buttressing loss, entering as factors on grounding-line
# flux $q_g \propto h_g^{\,s}$), and its shape parameter $\alpha$ captures the
# asymmetry from flux-nonlinearity amplification (Robel et al. 2019). The
# 5th and 95th percentiles are fixed to match the scenario bounds
# $(l, h)$ in log-space:
# $$\omega = \frac{\log h - \log l}{z_{0.95}(\alpha) - z_{0.05}(\alpha)}, \qquad \xi = \log l - \omega\, z_{0.05}(\alpha)$$
# so that $H_{2100} = \exp(X)$, $X \sim \text{SN}(\xi, \omega, \alpha)$.
#
# ---
#
# ## S2 trajectory
#
# S2's mass loss target follows a power-law ramp toward the drawn 2100
# endpoint:
# $$H_{\text{target}}(t) = H_{2100} \cdot R \cdot \left(\frac{t - t_0}{2100 - t_0}\right)^{\beta}$$
# where $R$ is the rheology endpoint correction (below). A pure power-law ramp with $\beta > 1$ forces the
# rate to zero at the anchor year, which is inconsistent with WAIS's
# nonzero observed present-day discharge. The realized S2 trajectory is
# instead a rate-space blend of $H_{\text{target}}$ with S1's data constrained
# quadratic continuation (§ S1 above), transitioning through a
# sigmoid window centered at $T_{\text{center}} = 2035$ with width
# $\tau = 5$ yr — the same blend rule and window used for the aggregate
# GMSL forecast (`component_forecast.ipynb`). Blending reshapes only how the
# trajectory approaches 2100, not the endpoint distribution.
#
# ---
#
# ## SSP Independence
#
# The combined distribution is SSP-independent. WAIS dynamics on
# projection timescales are driven primarily by subsurface ocean thermal
# forcing with long lag times of order decades, not contemporaneous surface
# warming. Naughten et al. (2023) find that rapid West Antarctic ice-shelf
# melting at ≈3× historical rates is unavoidable regardless of emissions
# scenario through at least 2100.
#
# ---
#
# ## Observations
#
# - **IMBIE West Antarctica** (Otosaka et al. 2023): 1992–2020, monthly,
#   cumulative ≈6.6 mm SLE. Structural break at ≈2010: acceleration
#   0.015 mm/yr² (1992–2010), deceleration −0.031 mm/yr² (2010–2020). Peak
#   rate ≈0.44 mm/yr around 2010–2012.
# - **Bamber et al. (2019) SEJ**: independent cross-check. Under +5°C, WAIS
#   5th–95th percentile: −50 to 930 mm (median 180 mm).
#
#
# ---
#
# ## References
#
# - Bamber, Oppenheimer, Kopp, Aspinall, & Cooke (2019). Ice sheet contributions to future sea-level rise from structured expert judgment. *PNAS* 116, 11195–11200.
# - Bassis & Walker (2012). Upper and lower limits on the stability of calving glaciers from the yield strength envelope of ice. *Proc. R. Soc. A* 468, 913–931.
# - Bons et al. (2018). Greenland Ice Sheet: higher nonlinearity of ice flow significantly reduces estimated basal motion. *GRL* 45, 6542–6548.
# - Clerc, Minchew, & Behn (2019). Marine ice cliff instability mitigated by slow removal of ice shelves. *GRL* 46, 12108–12116.
# - DeConto & Pollard (2016). Contribution of Antarctica to past and future sea-level rise. *Nature* 531, 591–597.
# - DeConto et al. (2021). The Paris Climate Agreement and future sea-level rise from Antarctica. *Nature* 593, 83–89.
# - Dow et al. (2022). Antarctic basal environment shaped by high-pressure flow through a subglacial river system. *Nature Geoscience* 15, 892–898.
# - Edwards et al. (2019). Revisiting Antarctic ice loss due to marine ice-cliff instability. *Nature* 566, 58–64.
# - Fan et al. (2025). A meta-analysis of ice creep experiments. *JGR Solid Earth*.
# - Fox-Kemper et al. (2021). Ocean, cryosphere and sea level change. In *IPCC AR6 WGI*, Ch. 9.
# - Getraer & Morlighem (2025). Higher Glen's flow law exponent increases Amundsen Sea Embayment contribution to SLR. *GRL*.
# - Goldberg, Morlighem, & Gourmelen (2026). Recent observations of Thwaites Glacier, West Antarctica are consistent with high rates of loss in next 50 years. *GRL* 53, e2025GL118823.
# - Graham et al. (2022). Rapid retreat of Thwaites Glacier in the pre-satellite era. *Nature Geoscience* 15, 706–713.
# - Joughin, Smith, & Medley (2014). Marine ice sheet collapse potentially under way for the Thwaites Glacier Basin, West Antarctica. *Science* 344, 735–738.
# - Martin, Kachuck, Trevers, Millstein, Cornford, & Minchew (2026). Rates of sea-level rise are highly sensitive to ice viscosity parameters in model benchmarks. *AGU Advances* 7(2).
# - Millstein, Minchew, & Pegler (2022). Ice viscosity is more sensitive to stress than commonly assumed. *Communications Earth & Environment* 3, 57.
# - Morlighem et al. (2024). The West Antarctic ice sheet may not be vulnerable to marine ice cliff instability during the 21st century. *Science Advances* 10, eado7794.
# - Morlighem et al. (2020). Deep glacial troughs and stabilizing ridges unveiled beneath the margins of the Antarctic ice sheet. *Nature Geoscience* 13, 132–137.
# - Naughten et al. (2023). Unavoidable future increase in West Antarctic ice-shelf melting over the twenty-first century. *Nature Climate Change* 13, 1222–1228.
# - Otosaka et al. (2023). Mass balance of the Greenland and Antarctic ice sheets from 1992 to 2020. *Earth System Science Data* 15, 1597–1616.
# - Pfeffer, Harper, & O'Neel (2008). Kinematic constraints on glacier contributions to 21st-century sea-level rise. *Science* 321, 1340–1343.
# - Ranganathan & Minchew (2024). A modified viscous flow law for natural glacier ice: Scaling from laboratories to ice sheets. *PNAS* 121(23).
# - Rignot et al. (2026). Thirty years of glacier grounding line retreat in Antarctica. *PNAS* 123(10), e2524380123.
# - Robel, Seroussi, & Roe (2019). Marine ice sheet instability amplifies and skews uncertainty in projections of future sea-level rise. *PNAS* 116, 14887–14892.
# - Schlemm, Feldmann, Winkelmann, & Levermann (2022). Stabilizing effect of mélange buttressing on the marine ice-cliff instability of the West Antarctic Ice Sheet. *The Cryosphere* 16, 1979–1996.
# - Schoof (2007). Ice sheet grounding line dynamics: steady states, stability, and hysteresis. *JGR Earth Surface* 112, F03S28.
# - Schoof (2012). Marine ice sheet stability. *J. Fluid Mech.* 698, 62–72.
# - Seroussi et al. (2020). ISMIP6 Antarctica: a multi-model ensemble of the Antarctic ice sheet evolution over the 21st century. *The Cryosphere* 14, 3033–3070.
# - Joughin, Shapero, Dutrieux, & Smith (2021). Ocean-induced melt volume directly paces ice loss from Pine Island Glacier. *Science Advances* 7, eabi5738.
# - Jourdain et al. (2022). Ice shelf basal melt rates in the Amundsen Sea at the end of the 21st century. *GRL* 49, e2022GL100629.
# - van den Akker et al. (2025). Present-day forcing is sufficient for large-scale retreat of the West Antarctic ice sheet. *Nature Geoscience*.

# %%
import sys, os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from pathlib import Path
sys.path.insert(0, str(Path('.').resolve() / 'arete_mpl'))
import arete_mpl
arete_mpl.use('poster')
plt.rcParams.update({
  'figure.dpi': 150,
  'font.size': 10,
  'axes.labelsize': 11,
  'legend.fontsize': 9,
})

sys.path.insert(0, '.')
from slr_data_readers import read_imbie_west_antarctica
from component_analysis import annualize_imbie
from component_projections import (
    sample_a4_wais, sample_a4_wais_endpoint, sample_a4_wais_trajectories,
    A4_SCENARIOS, RHEOLOGY_FACTOR_MEDIAN,
    RHEOLOGY_FACTOR_SIGMA, _sample_log_skewnormal,
    N_OBS_MEAN, N_OBS_SIGMA, N_REF, RHEOLOGY_SENSITIVITY,
    read_ipcc_component_nc, ipcc_extract, read_ipcc_workflow_samples,
    WAIS_ONSET_YEAR,
    S1_QUADRATIC_MEAN, S1_QUADRATIC_COV, _sample_s1_quadratic_mm,
)
from component_plotting import (
    SSP_COLORS, COMP_COLORS,
    plot_component_projection_twopanel,
    plot_component_histogram,
    plot_component_pdf_exceedance,
    plot_a4_scenario_pdfs,
    plot_component_ridge,
)

H5_PATH = '../data/processed/slr_processed_data.h5'
RAW_DIR = '../data/raw'
FIG_DIR = '../figures'
CONF_BASE = f'{RAW_DIR}/ipcc_ar6/slr/ar6/global/confidence_output_files'
WORKFLOW_BASE = f'{RAW_DIR}/ipcc_ar6/slr/ar6/global/full_sample_workflows'

from slr_forecast.config import BASELINE_YEAR, Z_90
from slr_forecast import M_TO_MM

# ── Sample count ──
# Override to 10k for stable tail quantiles in the skew-normal mixture.
# The 10%-weighted S1 and S3 scenarios get ~1000 samples each, giving
# ±11 mm stability at p95 vs ±23 mm at 2k.  The export cell (§6)
# downsamples to 2k for component_forecast.ipynb where all components
# share N_SAMPLES=2000.
N_SAMPLES = 10_000

# ── Rheology mode ──
# 'A': Independent corrections (endpoint R drawn separately from beta correction)
# 'B': Unified n-driven corrections (single n draw drives both R and beta)
# Mode B is used for published results: a single n draw couples the endpoint
# and trajectory corrections, which is more physically consistent.
RHEOLOGY_MODE = 'B'

print(f'WAIS onset year: {WAIS_ONSET_YEAR:.0f}')
print(f'N_SAMPLES = {N_SAMPLES}')
# Out:
# WAIS onset year: 2010
# N_SAMPLES = 10000

# %% [markdown]
# ## 1. Data Loading

# %%
df_wais = read_imbie_west_antarctica(f'{RAW_DIR}/ice_sheets/antarctica/imbie_west_antarctica_2021_mm.csv')
wais_year, wais_rebase, wais_sigma = annualize_imbie(df_wais, baseline_year=BASELINE_YEAR)

print(f'WAIS IMBIE: {wais_year[0]:.0f}–{wais_year[-1]:.0f}, {len(wais_year)} points')
print(f'WAIS cumulative at end: {wais_rebase[-1]*M_TO_MM:.1f} mm')
# Out:
# WAIS IMBIE: 1992–2020, 29 points
# WAIS cumulative at end: 5.8 mm

# %% [markdown]
# ## 2. Scenario Framework
#
# ### Scenario structure
#
# | Scenario | P | 2100 range (mm) | Distribution | Physics |
# |----------|---|-----------------|--------------|---------|
# | S1: Status quo | 10% | median 90, [61, 118] (90% CI) | Direct posterior (quadratic-in-time fit to IMBIE) | No MISI |
# | S2: Fast WAIS (MISI+MICI) | 90% | 130–1300 (5th/95th) | Skew-normal in log-space, α=3 | MISI, with or without ice-cliff cascade; upper bound pinned to AR6 low-confidence AIS p95 (SSP5-8.5) |
#
# ### Distribution
# - **S1**: sampled directly from `S1_QUADRATIC_MEAN`/`S1_QUADRATIC_COV`, a Bayesian quadratic-in-time fit to the IMBIE 1992-2020 record (§3 below). No skew-normal, no `low_mm`/`high_mm`/α.
# - **S2**: skew-normal in log-space; 5th/95th percentiles anchored to low/high bounds, α controls skewness. α=3 is a representative literature value for MISI's flux-nonlinearity amplification (Robel et al. 2019); the mixture is insensitive to its precise value — see cell 0.
# - S2's upper bound (1300 mm) is pinned to the IPCC AR6 low-confidence AIS p95 under SSP5-8.5 (1309 mm, rounded; Fox-Kemper et al. 2021). Its lower bound (130 mm) is pinned to the 99th percentile of S1's endpoint distribution — see cell 0.
#
# ### Trajectory
# - **S1**: the quadratic-in-time posterior curve itself, spliced onto the observed record at the anchor year.
# - **S2**: a power-law ramp toward the drawn 2100 endpoint, exponent β(n) (rheology-corrected), rate-space blended with S1's quadratic near the anchor year (sigmoid window centered 2035, width 5 yr — same rule as the aggregate forecast's blend) and rescaled to keep H(2100) exact. β(n) is therefore the pre-blend target shape only; the realized path is instead summarized by an effective exponent at 2035/2050 — see cell 0.
#
# ### Corrections applied
# - **Rheology** (n=3→n≈4.1, Martin et al. 2026): applied to **S2 only**, factor 1.28 ± 0.07 on the endpoint and β(n) on the (pre-blend) trajectory exponent. Not applied to S1, which is grounded in observed mass balance rather than an ISMIP6-class model.

# %%
# A4 scenario mixture: S1, S2, combined, IPCC AR6 medium- and low-confidence
# p-box percentile markers, and the real constituent AIS workflows (ISMIP6
# emulator, LARMIP-2, MICI, SEJ) on the left; combined and both IPCC p-box
# exceedance curves (built directly from their quantile arrays, not a
# Gaussian/KDE approximation) on the right. The p-box itself has no PDF --
# it is a min/mean-of-medians/max envelope across structurally different
# ice-sheet workflows (Kriegler & Held 2005; Le Cozannet et al. 2017; AR6
# Ch.9 SS9.6.3.2) -- so rather than fitting one to it, the PDF panel shows
# each constituent workflow's own (genuine) distribution plus the p-box's
# exact assessed percentiles as markers.
from scipy.stats import gaussian_kde

rng_scenarios = np.random.default_rng(42)
child_rngs = rng_scenarios.spawn(len(A4_SCENARIOS))

scenario_colors = {'S1_status_quo': 'C0', 'S2_fast_wais': 'C1'}
scenario_samples = {}
scenario_labels = {}
for (sname, params), s_rng in zip(A4_SCENARIOS.items(), child_rngs):
    weights = {s: (1.0 if s == sname else 0.0) for s in A4_SCENARIOS}
    scenario_samples[sname] = sample_a4_wais_endpoint(
        200000, s_rng, rheology_mode=RHEOLOGY_MODE,
        scenario_overrides={'weights': weights},
    )
    scenario_labels[sname] = f'{sname.replace("_", " ")} (P={params["P"]:.0%})'

mixture_m = sample_a4_wais_endpoint(200000, np.random.default_rng(99),
                                     rheology_mode=RHEOLOGY_MODE)

# IPCC AR6 medium-confidence p-box (total AIS). NOTE: IPCC reports only
# total AIS (EAIS + Peninsula + WAIS), not WAIS alone -- this comparison is
# intentionally asymmetric, shown for reference against the WAIS-only A4
# mixture. Used for the exceedance curve (direct from quantiles) and PDF-
# panel percentile markers only -- the p-box itself is not a distribution.
ipcc_data = read_ipcc_component_nc(CONF_BASE, 'medium_confidence', 'ssp245', 'AIS')
yr_idx = np.argmin(np.abs(ipcc_data['years'] - 2100))
med_exc_vals_m = ipcc_data['slc'][:, yr_idx] / M_TO_MM
med_exc_pct = (1.0 - ipcc_data['quantiles']) * 100
ex_med = ipcc_extract(ipcc_data, quantiles_target=(0.50, 0.83, 0.95))
med_pctiles = {50: ex_med['q50'][yr_idx] / M_TO_MM,
               83: ex_med['q83'][yr_idx] / M_TO_MM,
               95: ex_med['q95'][yr_idx] / M_TO_MM}

# IPCC AR6 low-confidence p-box (total AIS, SSP5-8.5), same treatment.
ipcc_low = read_ipcc_component_nc(CONF_BASE, 'low_confidence', 'ssp585', 'AIS')
yr_low = np.argmin(np.abs(ipcc_low['years'] - 2100))
low_exc_vals_m = ipcc_low['slc'][:, yr_low] / M_TO_MM
low_exc_pct = (1.0 - ipcc_low['quantiles']) * 100
ex_low = ipcc_extract(ipcc_low, quantiles_target=(0.50, 0.83, 0.95))
low_pctiles = {50: ex_low['q50'][yr_low] / M_TO_MM,
               83: ex_low['q83'][yr_low] / M_TO_MM,
               95: ex_low['q95'][yr_low] / M_TO_MM}

# Constituent AIS workflows underlying the p-boxes (real single-model
# distributions, unlike the p-box envelope itself). ISMIP6 emulator and
# LARMIP-2 drive the medium-confidence p-box (SSP2-4.5, matching ipcc_data
# above); MICI and SEJ are the additional processes folded in for low
# confidence (SSP5-8.5, matching ipcc_low above).
ismip6_med = read_ipcc_workflow_samples(
    WORKFLOW_BASE, 'wf_1e', 'ssp245',
    'icesheets-ipccar6-ismipemuicesheet-ssp245_AIS_globalsl.nc') / M_TO_MM
larmip_med = read_ipcc_workflow_samples(
    WORKFLOW_BASE, 'wf_2e', 'ssp245',
    'icesheets-ipccar6-larmipicesheet-ssp245_TOT_globalsl.nc') / M_TO_MM
mici_low = read_ipcc_workflow_samples(
    WORKFLOW_BASE, 'wf_3e', 'ssp585',
    'icesheets-dp20-icesheet-ssp585_AIS_globalsl.nc') / M_TO_MM
sej_low = read_ipcc_workflow_samples(
    WORKFLOW_BASE, 'wf_4', 'ssp585',
    'icesheets-ipccar6-bambericesheet-ssp585_AIS_globalsl.nc') / M_TO_MM

# Each series lists which panel(s) it appears in: 'pdf', 'exc', or both.
# The four AIS workflow entries are thinner/unfilled to keep them visually
# secondary to the WAIS A4 mixture, which is the notebook's primary result.
series = [
    dict(samples=scenario_samples['S1_status_quo'],
         label=scenario_labels['S1_status_quo'],
         color=scenario_colors['S1_status_quo'], panels=('pdf', 'exc'),
         lw=2, alpha_fill=0.35),
    dict(samples=scenario_samples['S2_fast_wais'],
         label=scenario_labels['S2_fast_wais'],
         color=scenario_colors['S2_fast_wais'], panels=('pdf', 'exc'),
         lw=2, alpha_fill=0.35),
    dict(samples=mixture_m, label='Combined (A4 mixture)', color='black',
         panels=('pdf', 'exc'), lw=2, alpha_fill=0.35),
    dict(samples=ismip6_med, label='AIS: ISMIP6 emulator (med conf, SSP2-4.5)',
         color='tab:orange', panels=('pdf',), lw=1.3, alpha_fill=0.0),
    dict(samples=larmip_med, label='AIS: LARMIP-2 (med conf, SSP2-4.5)',
         color='tab:purple', panels=('pdf',), lw=1.3, alpha_fill=0.0),
    dict(samples=mici_low, label='AIS: MICI, DeConto+21 (low conf, SSP5-8.5)',
         color='firebrick', panels=('pdf',), lw=1.3, alpha_fill=0.0, ls='--'),
    dict(samples=sej_low, label='AIS: SEJ, Bamber+19 (low conf, SSP5-8.5)',
         color='mediumvioletred', panels=('pdf',), lw=1.3, alpha_fill=0.0, ls='--'),
]

LEGEND_FONTSIZE = 12  # matches component_greenland_discharge_delay_fit.png
TICK_FONTSIZE = 12
LABEL_FONTSIZE = 14

fig, (ax_pdf, ax_exc) = plt.subplots(1, 2, figsize=(14, 5))
xlabel = 'WAIS / AIS SLR at 2100 (m)'
xlim = (-0.6, 3.0)  # extended to show the full spread of all PDF curves

# KDE x range, from the union of all series shown
all_vals = np.concatenate([s['samples'] for s in series if len(s['samples']) > 0])
data_range = np.percentile(all_vals, 99.9) - np.percentile(all_vals, 0.1)
x_lo = np.percentile(all_vals, 0.1) - 0.5 * data_range
x_hi = np.percentile(all_vals, 99.9) + 0.5 * data_range
x_grid = np.linspace(x_lo, x_hi, 1000)
dx = x_grid[1] - x_grid[0]

kde_curves = []
for s in series:
    samples, label, color = s['samples'], s['label'], s['color']
    if len(samples) < 10:
        continue
    # Some IPCC workflow ensembles (e.g. MICI) are resampled from far
    # fewer underlying discrete model realizations than the nominal
    # sample count; Scott's rule scales bandwidth with len(samples),
    # which under-smooths in that case. Use the effective (unique-value)
    # sample size instead.
    n_eff = len(np.unique(samples))
    bw = n_eff ** (-1 / 5) if n_eff < len(samples) else 'scott'
    kde = gaussian_kde(samples, bw_method=bw)
    density = kde(x_grid)

    if 'pdf' in s['panels']:
        prob = density * dx * 100
        if s.get('alpha_fill', 0) > 0:
            ax_pdf.fill_between(x_grid, 0, prob, color=color, alpha=s['alpha_fill'])
        ax_pdf.plot(x_grid, prob, color=color, lw=s.get('lw', 2),
                    ls=s.get('ls', '-'), label=label)
        kde_curves.append((x_grid, prob, color, samples, s.get('alpha_fill', 0) > 0))

    if 'exc' in s['panels']:
        cdf = np.cumsum(density) * dx
        ax_exc.plot(x_grid, (1.0 - cdf) * 100, color=color, lw=2, label=label)

if med_exc_vals_m is not None:
    ax_exc.plot(med_exc_vals_m, med_exc_pct, color='tab:red', lw=2,
                label='IPCC AR6 p-box (medium conf, total AIS)')

if low_exc_vals_m is not None:
    ax_exc.plot(low_exc_vals_m, low_exc_pct, color='tab:red', ls='--', lw=2,
                label='IPCC AR6 p-box (low conf SSP5-8.5, total AIS)')

# Fix the PDF panel's y-limit before placing text relative to it.
ax_pdf.set_ylim(0, 5)

# Truncated median lines: clip to the PDF envelope height at the median.
# Only for the "real" filled A4-mixture distributions -- the thin AIS
# workflow reference curves are left unmarked to reduce clutter.
for x_k, prob_k, color_k, samples_k, is_primary in kde_curves:
    if not is_primary:
        continue
    med = np.median(samples_k)
    idx_med = np.argmin(np.abs(x_k - med))
    ymax = min(prob_k[idx_med], ax_pdf.get_ylim()[1])
    ax_pdf.vlines(med, 0, ymax, color=color_k, ls='--', lw=1, alpha=0.7)

# IPCC AR6 p-box percentile markers (exact assessed values from the
# quantile arrays, not read off the constituent-workflow KDEs). White-
# filled boxes behind the numbers keep the closely-spaced labels legible.
def add_pctile_markers(ax, pctiles, color, label):
    for pct, val in sorted(pctiles.items()):
        ax.axvline(val, color=color, ls=':', lw=1.3, alpha=0.7)
        ax.text(val, ax.get_ylim()[1] * 0.97, f'{pct}', color=color, fontsize=9,
                ha='center', va='top', fontweight='bold',
                bbox=dict(boxstyle='round,pad=0.15', facecolor='white',
                          edgecolor='none', alpha=0.85))
    # Single legend entry for the p-box percentile lines
    ax.axvline(np.nan, color=color, ls=':', lw=1.3, label=label)

add_pctile_markers(ax_pdf, med_pctiles, 'darkred',
                    'IPCC AR6 p-box percentiles (medium conf)')
add_pctile_markers(ax_pdf, low_pctiles, 'tab:orange',
                    'IPCC AR6 p-box percentiles (low conf SSP5-8.5)')

ax_pdf.set_xlabel(xlabel, fontsize=LABEL_FONTSIZE)
ax_pdf.set_ylabel('Probability (%)', fontsize=LABEL_FONTSIZE)
ax_pdf.legend(fontsize=LEGEND_FONTSIZE, loc='center right')
ax_pdf.set_xlim(*xlim)
ax_pdf.grid(True, alpha=0.2)
ax_pdf.tick_params(labelsize=TICK_FONTSIZE)

ax_exc.set_xlabel(xlabel, fontsize=LABEL_FONTSIZE)
ax_exc.set_ylabel('P(exceedance) (%)', fontsize=LABEL_FONTSIZE)
ax_exc.legend(fontsize=LEGEND_FONTSIZE)
ax_exc.set_ylim(0, 100)
ax_exc.set_xlim(*xlim)
ax_exc.grid(True, alpha=0.2)
ax_exc.tick_params(labelsize=TICK_FONTSIZE)

plt.tight_layout()
plt.savefig(f'{FIG_DIR}/component_wais_pdf_exceedance_ipcc.png',
            dpi=150, bbox_inches='tight')
plt.show()

# %%
# Mirror of the cell above (component_wais_pdf_exceedance_ipcc.png): same
# IPCC AR6 p-box context and the four constituent AIS workflow curves
# (ISMIP6 emulator, LARMIP-2, MICI DeConto, SEJ Bamber), but replaces the
# S1/S2/combined-mixture triad with a p(S1) weight sweep of the A4 mixture
# itself -- p(S1) = 0.0, 0.1, ..., 1.0 (S2_fast_wais weight = 1 - p(S1) in
# each case; p(S1)=0.0 is the pure S2_fast_wais end member, included for
# completeness) -- colored on a viridis colormap, with a colorbar (not a
# per-line legend entry) showing the p(S1) range. Draw order (zorder) puts
# the IPCC AR6 constituent-workflow and p-box curves on top of the
# scenario-mixture curves, and among the mixture curves themselves, smaller
# p(S1) on top of larger p(S1). Axis limits, panel layout, and font sizes
# are identical to the mirrored cell so the two figures are directly
# comparable.
from scipy.stats import gaussian_kde
import matplotlib.colors as mcolors
import matplotlib.ticker as mticker

p_s1_sweep = [round(0.1 * i, 1) for i in range(0, 11)]
_sweep_cmap = plt.cm.viridis
sweep_colors = {p: _sweep_cmap(p) for p in p_s1_sweep}

sweep_samples = {}
sweep_labels = {}
for i, p_s1 in enumerate(p_s1_sweep):
    weights = {'S1_status_quo': p_s1, 'S2_fast_wais': 1.0 - p_s1}
    sweep_samples[p_s1] = sample_a4_wais_endpoint(
        200000, np.random.default_rng(5000 + i), rheology_mode=RHEOLOGY_MODE,
        scenario_overrides={'weights': weights},
    )
    sweep_labels[p_s1] = f'Mixture (p(S1)={p_s1:.0%})'

# IPCC AR6 medium-confidence p-box (total AIS) -- identical to the mirrored cell.
ipcc_data = read_ipcc_component_nc(CONF_BASE, 'medium_confidence', 'ssp245', 'AIS')
yr_idx = np.argmin(np.abs(ipcc_data['years'] - 2100))
med_exc_vals_m = ipcc_data['slc'][:, yr_idx] / M_TO_MM
med_exc_pct = (1.0 - ipcc_data['quantiles']) * 100
ex_med = ipcc_extract(ipcc_data, quantiles_target=(0.05, 0.50, 0.95))
med_pctiles = {5: ex_med['q05'][yr_idx] / M_TO_MM,
               50: ex_med['q50'][yr_idx] / M_TO_MM,
               95: ex_med['q95'][yr_idx] / M_TO_MM}

# IPCC AR6 low-confidence p-box (total AIS, SSP5-8.5), same treatment.
ipcc_low = read_ipcc_component_nc(CONF_BASE, 'low_confidence', 'ssp585', 'AIS')
yr_low = np.argmin(np.abs(ipcc_low['years'] - 2100))
low_exc_vals_m = ipcc_low['slc'][:, yr_low] / M_TO_MM
low_exc_pct = (1.0 - ipcc_low['quantiles']) * 100
ex_low = ipcc_extract(ipcc_low, quantiles_target=(0.05, 0.50, 0.95))
low_pctiles = {5: ex_low['q05'][yr_low] / M_TO_MM,
               50: ex_low['q50'][yr_low] / M_TO_MM,
               95: ex_low['q95'][yr_low] / M_TO_MM}

# Constituent AIS workflows underlying the p-boxes -- identical to the
# mirrored cell (ISMIP6 emulator and LARMIP-2 drive medium confidence;
# MICI and SEJ are the additional processes folded into low confidence).
ismip6_med = read_ipcc_workflow_samples(
    WORKFLOW_BASE, 'wf_1e', 'ssp245',
    'icesheets-ipccar6-ismipemuicesheet-ssp245_AIS_globalsl.nc') / M_TO_MM
larmip_med = read_ipcc_workflow_samples(
    WORKFLOW_BASE, 'wf_2e', 'ssp245',
    'icesheets-ipccar6-larmipicesheet-ssp245_TOT_globalsl.nc') / M_TO_MM
mici_low = read_ipcc_workflow_samples(
    WORKFLOW_BASE, 'wf_3e', 'ssp585',
    'icesheets-dp20-icesheet-ssp585_AIS_globalsl.nc') / M_TO_MM
sej_low = read_ipcc_workflow_samples(
    WORKFLOW_BASE, 'wf_4', 'ssp585',
    'icesheets-ipccar6-bambericesheet-ssp585_AIS_globalsl.nc') / M_TO_MM

# Series list: the eleven p(S1)-weighted mixtures (viridis, both panels,
# no individual legend entry -- shown via colorbar instead; zorder ranks
# them smaller-p(S1)-on-top) plus the four AIS workflow curves (thin/
# unfilled, PDF panel only, drawn above all mixture curves via zorder=20).
series = [dict(samples=sweep_samples[p], label=sweep_labels[p],
               color=sweep_colors[p], panels=('pdf', 'exc'), lw=2.2,
               alpha_fill=0.0, primary=True, legend=False,
               zorder=len(p_s1_sweep) + 2 - i)
          for i, p in enumerate(p_s1_sweep)]
# Workflow-curve colors are chosen from outside viridis's purple-blue-
# green-yellow gamut (warm/neutral hues) so they stand out against the
# p(S1) sweep rather than blending with it -- tab:purple in particular
# was easily confused with the dark end of the viridis mixture curves.
series += [
    dict(samples=ismip6_med, label='ISMIP6 (mc)',
         color='#E69F00', panels=('pdf',), lw=2.3, alpha_fill=0.0,
         primary=False, zorder=20),
    dict(samples=larmip_med, label='LARMIP-2 (mc)',
         color='#8B4513', panels=('pdf',), lw=2.3, alpha_fill=0.0,
         primary=False, zorder=20),
    dict(samples=mici_low, label='MICI (lc)',
         color='#D62728', panels=('pdf',), lw=2.3, alpha_fill=0.0, ls='--',
         primary=False, zorder=20),
    dict(samples=sej_low, label='SEJ (lc)',
         color='#CC79A7', panels=('pdf',), lw=2.3, alpha_fill=0.0, ls='--',
         primary=False, zorder=20),
]

LEGEND_FONTSIZE = 12  # matches component_greenland_discharge_delay_fit.png
TICK_FONTSIZE = 12
LABEL_FONTSIZE = 14

fig, (ax_pdf, ax_exc) = plt.subplots(1, 2, figsize=(14, 5))
xlabel = 'WAIS GMSL at 2100 (m; relative to 2000)'
xlim = (-0.6, 3.0)  # matches the mirrored cell

# KDE x range, from the union of all series shown
all_vals = np.concatenate([s['samples'] for s in series if len(s['samples']) > 0])
data_range = np.percentile(all_vals, 99.9) - np.percentile(all_vals, 0.1)
x_lo = np.percentile(all_vals, 0.1) - 0.5 * data_range
x_hi = np.percentile(all_vals, 99.9) + 0.5 * data_range
x_grid = np.linspace(x_lo, x_hi, 1000)
dx = x_grid[1] - x_grid[0]

for s in series:
    samples, label, color = s['samples'], s['label'], s['color']
    if len(samples) < 10:
        continue
    # Some IPCC workflow ensembles (e.g. MICI) are resampled from far
    # fewer underlying discrete model realizations than the nominal
    # sample count; Scott's rule scales bandwidth with len(samples),
    # which under-smooths in that case. Use the effective (unique-value)
    # sample size instead.
    n_eff = len(np.unique(samples))
    bw = n_eff ** (-1 / 5) if n_eff < len(samples) else 'scott'
    kde = gaussian_kde(samples, bw_method=bw)
    density = kde(x_grid)
    plot_label = label if s.get('legend', True) else None

    if 'pdf' in s['panels']:
        prob = density * dx * 100
        if s.get('alpha_fill', 0) > 0:
            ax_pdf.fill_between(x_grid, 0, prob, color=color, alpha=s['alpha_fill'])
        ax_pdf.plot(x_grid, prob, color=color, lw=s.get('lw', 2),
                    ls=s.get('ls', '-'), label=plot_label,
                    zorder=s.get('zorder', 2))

    if 'exc' in s['panels']:
        cdf = np.cumsum(density) * dx
        ax_exc.plot(x_grid, (1.0 - cdf) * 100, color=color, lw=2, label=plot_label,
                    zorder=s.get('zorder', 2))

if med_exc_vals_m is not None:
    ax_exc.plot(med_exc_vals_m, med_exc_pct, color='tab:red', lw=2,
                label='IPCC AR6 (mc)', zorder=20)

if low_exc_vals_m is not None:
    ax_exc.plot(low_exc_vals_m, low_exc_pct, color='tab:red', ls='--', lw=2,
                label='IPCC AR6 (lc)', zorder=20)

# Fix the PDF panel's y-limit before placing text relative to it.
ax_pdf.set_ylim(0, 5)

# IPCC AR6 p-box percentile markers (exact assessed values from the
# quantile arrays, not read off the constituent-workflow KDEs). White-
# filled boxes behind the numbers keep the closely-spaced labels legible.
# Drawn at zorder=21/22 so they stay on top of every mixture and workflow
# curve (zorder<=20).
def add_pctile_markers(ax, pctiles, color, text_offset_pts=None):
    text_offset_pts = text_offset_pts or {}
    for pct, val in sorted(pctiles.items()):
        ax.axvline(val, color=color, ls=':', lw=1.3, alpha=0.7, zorder=21)
        ax.annotate(f'{pct}', xy=(val, ax.get_ylim()[1] * 0.97),
                    xytext=(text_offset_pts.get(pct, 0), 0),
                    textcoords='offset points',
                    color=color, fontsize=9, ha='center', va='top',
                    fontweight='bold', zorder=22,
                    bbox=dict(boxstyle='round,pad=0.15', facecolor='white',
                              edgecolor='none', alpha=0.85))

add_pctile_markers(ax_pdf, med_pctiles, 'darkred')
# Low-confidence 50th percentile label shifted 5 pts right (net, after a
# further 5 pt shift left) to clear the overlapping medium-confidence 50th
# percentile label at the same x.
add_pctile_markers(ax_pdf, low_pctiles, 'tab:orange', text_offset_pts={50: 5})

ax_pdf.set_xlabel(xlabel, fontsize=LABEL_FONTSIZE)
ax_pdf.set_ylabel('Probability (%)', fontsize=LABEL_FONTSIZE)
ax_pdf.legend(fontsize=LEGEND_FONTSIZE, loc='upper right')
ax_pdf.set_xlim(*xlim)
ax_pdf.grid(True, alpha=0.2)
ax_pdf.tick_params(labelsize=TICK_FONTSIZE)

ax_exc.set_xlabel(xlabel, fontsize=LABEL_FONTSIZE)
ax_exc.set_ylabel('P(exceedance) (%)', fontsize=LABEL_FONTSIZE)
ax_exc.legend(fontsize=LEGEND_FONTSIZE)
ax_exc.set_ylim(0, 100)
ax_exc.set_xlim(*xlim)
ax_exc.grid(True, alpha=0.2)
ax_exc.tick_params(labelsize=TICK_FONTSIZE)
# Labeled inside the empty right side of the panel (curves have already
# decayed to ~0 exceedance there) rather than past xlim, to avoid
# overlapping the colorbar attached to this axis below.
_exc_ref_lines = {50: 'median', 5: '5%'}
for _y, _ylabel in _exc_ref_lines.items():
    ax_exc.axhline(_y, color='grey', ls='--', lw=1, alpha=0.7, zorder=1)
    ax_exc.text(xlim[1] - 0.05 * (xlim[1] - xlim[0]), _y + 1, _ylabel,
                color='grey', fontsize=9, ha='right', va='bottom', zorder=1)

# Colorbar (replaces per-line legend entries for the viridis mixture sweep).
# One shared colorbar is enough -- both panels use the same p(S1)->color
# mapping, so it's attached to the exceedance (right) panel only.
_sweep_sm = plt.cm.ScalarMappable(cmap=_sweep_cmap, norm=mcolors.Normalize(vmin=0.0, vmax=1.0))
_sweep_sm.set_array([])
_cbar = fig.colorbar(_sweep_sm, ax=ax_exc, pad=0.02)
_cbar.set_label('p(S1) (%)', fontsize=LABEL_FONTSIZE)
_cbar.ax.tick_params(labelsize=TICK_FONTSIZE)
_cbar.ax.yaxis.set_major_formatter(mticker.PercentFormatter(xmax=1.0, decimals=0, symbol=''))

plt.tight_layout()
plt.savefig(f'{FIG_DIR}/component_wais_pdf_exceedance_ipcc_p_s1_sweep.png',
            dpi=150, bbox_inches='tight')
plt.show()

# %%
# ── Validation: cross-check A4 quantiles against manuscript claims ──
N_VALID = 500_000
rng_valid = np.random.default_rng(42)

s2 = A4_SCENARIOS['S2_fast_wais']
print(f'S2 bounds: {s2["low_mm"]}–{s2["high_mm"]} mm, α={s2["alpha"]:.2f}')

# Pre-correction S2 samples (no rheology)
s2_pre = _sample_log_skewnormal(N_VALID, s2['low_mm'], s2['high_mm'], s2['alpha'], rng_valid)
s2_pre_p5, s2_pre_med, s2_pre_p83, s2_pre_p95 = np.percentile(s2_pre, [5, 50, 83, 95])
print(f'\nS2 pre-correction:  median = {s2_pre_med:.0f} mm '
      f'[{s2_pre_p5:.0f}, {s2_pre_p95:.0f}], p83 = {s2_pre_p83:.0f} mm')

# Post-correction S2 samples (with rheology)
rheo_draws = rng_valid.normal(RHEOLOGY_FACTOR_MEDIAN, RHEOLOGY_FACTOR_SIGMA, N_VALID)
rheo_draws = np.maximum(rheo_draws, 1.0)
s2_post = s2_pre * rheo_draws
s2_post_p5, s2_post_med, s2_post_p95 = np.percentile(s2_post, [5, 50, 95])
print(f'S2 post-correction: median = {s2_post_med:.0f} mm '
      f'[{s2_post_p5:.0f}, {s2_post_p95:.0f}]')
print(f'Effective rheology factor on median: {s2_post_med / s2_pre_med:.2f}')

# S2 spans both MISI-only and MISI+MICI outcomes, so it is not directly
# comparable to Bamber et al. (2019)'s MISI-only conditional median
# (~250-300 mm): S2 also carries MICI's mass, and its 95th percentile is
# pinned ~300 mm higher (to the AR6 low-confidence p95). We therefore
# widen the comparison band rather than force an exact match, and
# separately check the AR6 p83 anchor.
print(f'\nBamber MISI-only conditional median: ~250–300 mm (reference, not a direct target)')
print(f'Our pre-correction S2 median:        ~{s2_pre_med:.0f} mm  '
      f'{"within widened range" if 240 <= s2_pre_med <= 400 else "OUTSIDE expected range"}')
print(f'\nAR6 low-confidence AIS p83 (SSP5-8.5): ~600 mm (secondary reference, not exactly matched by construction)')
print(f'Our pre-correction S2 p83:              ~{s2_pre_p83:.0f} mm')

# Full A4 mixture quantiles
mix = sample_a4_wais_endpoint(N_VALID, np.random.default_rng(99),
                               rheology_mode=RHEOLOGY_MODE)
mix_p5, mix_med, mix_p95 = np.percentile(mix, [5, 50, 95])
print(f'\nFull A4 mixture at 2100: median = {mix_med*M_TO_MM:.0f} mm '
      f'[{mix_p5*M_TO_MM:.0f}, {mix_p95*M_TO_MM:.0f}] mm')
print(f'                      = {mix_med:.2f} m '
      f'[{mix_p5:.2f}, {mix_p95:.2f}] m')
# Out:
# S2 bounds: 130–1000 mm, α=3.00
#
# S2 pre-correction:  median = 290 mm [130, 1001], p83 = 570 mm
# S2 post-correction: median = 371 mm [165, 1285]
# Effective rheology factor on median: 1.28
#
# Bamber MISI-only conditional median: ~250–300 mm (reference, not a direct target)
# Our pre-correction S2 median:        ~290 mm  within widened range
#
# AR6 low-confidence AIS p83 (SSP5-8.5): ~600 mm (secondary reference, not exactly matched by construction)
# Our pre-correction S2 p83:              ~570 mm
#
# Full A4 mixture at 2100: median = 296 mm [75, 1162] mm
#                       = 0.30 m [0.07, 1.16] m

# %% [markdown]
# ## 3. Diagnostics & Validation

# %% [markdown]
# ### Bayesian quadratic-in-time fit (basis for S1_status_quo, §4)
#
# We fit a Bayesian curve to the WAIS record using the same machinery as
# the other components' level-space fits (`bayesian_models.fit_bayesian_level`,
# an `emcee` ensemble sampler) and the same correlation-aware uncertainty
# correction (`component_levelspace_robust_se`) — but with elapsed time
# since baseline as the covariate instead of temperature, since WAIS has
# no calibrated rate-temperature relationship.
#
# The model treats the WAIS mass-loss rate as changing linearly with
# elapsed time, rate(t) = a·(t - 2000) + v, so the cumulative curve is
# quadratic in t: H(t) = 0.5a(t-2000)² + v(t-2000) + H₀ — position under
# constant acceleration, with $a$ the acceleration, $v$ the velocity
# (rate) at t=2000, and $H_0$ the value at t=2000. The acceleration $a$
# has no directional physical constraint (WAIS's own record shows both
# acceleration through ≈2010 and deceleration after), so it is given a
# signed prior (`symmetric_a=True`) rather than a non-negative one.
#
# This fit is the direct basis for S1_status_quo (§4): S1 has no MISI, so
# its 2100 endpoint and pre-2100 trajectory are sampled from this fitted
# $(a, v, H_0)$ posterior (`S1_QUADRATIC_MEAN`/`_COV`,
# `_sample_s1_quadratic_mm()`), spliced onto the observed record at the
# anchor year. It is not used for S2, since a smooth curve cannot
# represent a future MISI onset.

# %%
# ── Bayesian quadratic-in-time fit: basis for S1_status_quo (§4) ──
# Same Bayesian machinery as component_glacier/apeninsula/eais.ipynb
# (fit_bayesian_level, emcee) and the same correlation-aware CI correction
# (component_levelspace_robust_se), but with elapsed time as the covariate
# instead of temperature. The fitted (a, v, H0) posterior feeds
# S1_QUADRATIC_MEAN/_COV in component_projections.py directly -- see
# markdown above for scope and caveats.
from bayesian_models import fit_bayesian_level
from component_analysis import model_ensemble_draws
from component_levelspace_robust_se import robust_level_intervals, robust_curve_band

_tau = wais_year - BASELINE_YEAR

# Design vectors for rate(t) = a*(t - BASELINE_YEAR) + v, i.e. H(t)
# quadratic in elapsed time (kinematics form: H = 0.5*a*t^2 + v*t + H0,
# with t measured from BASELINE_YEAR). Acceleration (a) is mapped onto
# fit_bayesian_level's 'a' slot with symmetric_a=True (signed Normal
# prior -- no physical reason to force a >= 0 for a purely descriptive
# time-based fit, unlike the warming-sensitivity priors used elsewhere).
# The 'b' slot (I1) is left inert (zero design column): fit_bayesian_level
# always forces b >= 0, which is harmless here since it never contributes
# to H(t).
#
# NOTE: I2 must use CENTERED elapsed time (0.5*tau**2), not raw year
# (0.5*(year**2 - BASELINE_YEAR**2)) -- the latter is ~1000x-collinear
# with I0 = tau over a 28-year window near year~2000 (since
# year + BASELINE_YEAR is nearly constant across the record), which
# starves the MCMC of a data constraint and forces the fit toward its
# priors instead. Caught via the MAP/posterior-median ratio diagnostic
# printed below by robust_level_intervals (ratio should be close to 1.0;
# the raw-year design gave ~1.4, flagged as unreliable).
I2_wais_t = 0.5 * _tau**2
I1_wais_t = np.zeros_like(_tau)
I0_wais_t = _tau

PRIOR_SCALE_A_WAIS = 5e-5   # Normal sigma on acceleration, m/yr^2
PRIOR_V_MEAN_WAIS = 0.0
PRIOR_V_SIGMA_WAIS = 0.002  # m/yr -- weakly informative
PRIOR_SIGMA_EXTRA_WAIS = 0.001
PRIOR_H0_SIGMA_WAIS = 0.005

_wais_bayes_t = fit_bayesian_level(
    H_obs=wais_rebase, sigma_obs=wais_sigma,
    I2_obs=I2_wais_t, I1_obs=I1_wais_t, I0_obs=I0_wais_t,
    symmetric_a=True,
    prior_scale_a=PRIOR_SCALE_A_WAIS, prior_scale_b=0.010,
    prior_c_mean=PRIOR_V_MEAN_WAIS, prior_c_sigma=PRIOR_V_SIGMA_WAIS,
    prior_sigma_extra_scale=PRIOR_SIGMA_EXTRA_WAIS,
    prior_H0_sigma=PRIOR_H0_SIGMA_WAIS,
    n_samples=4000, n_walkers=32, n_burnin=2000, thin=2, seed=700,
    progress=False)

# Correlation-aware 90% CI (see component_levelspace_robust_se.py): the
# raw MCMC posterior treats each point of this cumulative record as
# independent and understates the interval, same issue corrected for
# panels (a)-(c) of fig_s0_component_fit_diagnostics.png. Reorder the
# posterior into robust_level_intervals' expected (_, b, c) column
# layout: acceleration draws (real column 0, library's "a" slot) go in
# column 1; velocity draws (real column 2, library's "c" slot) are
# unchanged.
_post_view = np.zeros_like(_wais_bayes_t.posterior_samples)
_post_view[:, 1] = _wais_bayes_t.posterior_samples[:, 0]
_post_view[:, 2] = _wais_bayes_t.posterior_samples[:, 2]

_wais_robust_t = robust_level_intervals(
    wais_year, wais_rebase, wais_sigma, I2_wais_t, I0_wais_t,
    prior_scale_b=PRIOR_SCALE_A_WAIS, prior_c_mean=PRIOR_V_MEAN_WAIS,
    prior_c_sigma=PRIOR_V_SIGMA_WAIS, prior_H0_sigma=PRIOR_H0_SIGMA_WAIS,
    baseline_year=BASELINE_YEAR, posterior_samples=_post_view, conf=0.90,
    verbose=True)

# Median curve from the real posterior (I2 slot carries acceleration,
# un-zeroed -- opposite convention from glacier/apeninsula/eais' panel,
# which forces the quadratic term to zero for display).
np.random.seed(42)
_t_grid = np.linspace(wais_year.min(), wais_year.max(), 200)
_tau_grid = _t_grid - BASELINE_YEAR
_I2_grid = 0.5 * _tau_grid**2
_I0_grid = _tau_grid
_H_ens = model_ensemble_draws(_wais_bayes_t, _I2_grid, np.zeros_like(_tau_grid), _I0_grid)
_wais_bayes_p50 = np.median(_H_ens, axis=0) * M_TO_MM
_, _wais_bayes_lo, _wais_bayes_hi = robust_curve_band(_wais_robust_t, _I2_grid, _I0_grid, conf=0.90)
_wais_bayes_lo, _wais_bayes_hi = _wais_bayes_lo * M_TO_MM, _wais_bayes_hi * M_TO_MM

# Cross-check against the plain-WLS anchored quadratic used in
# fig_s0_component_fit_diagnostics.png panel (d) (component_levelspace_robust_se.
# robust_quadratic_level_fit): that gave a curvature term ~ 0.015 mm/yr^2,
# linear term ~ 0.16-0.19 mm/yr (order-of-magnitude only -- different
# parametrization/H0 treatment; that function uses its own m/c naming).
_a_med = np.median(_wais_bayes_t.posterior_samples[:, 0]) * M_TO_MM
_v_med = np.median(_wais_bayes_t.posterior_samples[:, 2]) * M_TO_MM
print(f'Bayesian fit: acceleration a = {_a_med:.4f} mm/yr^2, velocity v = {_v_med:.4f} mm/yr')

# S1_QUADRATIC_MEAN/_COV in component_projections.py are copied from here
# (beta_map_vec = [a, v, H0] in meters; cov_robust is the correlation-aware
# covariance for the same three parameters). Rerun this cell and paste
# these values into component_projections.py after refitting.
print(f"S1_QUADRATIC_MEAN (a, v, H0) = {_wais_robust_t['beta_map_vec']!r}")
print(f"S1_QUADRATIC_COV =\n{_wais_robust_t['cov_robust']!r}")

# Residual check across the structural break, for QC only -- small and
# unbiased residuals here just confirm the quadratic interpolates the
# historical record reasonably well; see markdown above for why that
# does not bear on whether it is safe to extrapolate forward.
_H_model_obs = model_ensemble_draws(_wais_bayes_t, I2_wais_t, np.zeros_like(_tau), I0_wais_t).mean(axis=0)
_resid_mm = (wais_rebase - _H_model_obs) * M_TO_MM
_pre = wais_year < WAIS_ONSET_YEAR
_post = ~_pre
print(f'Mean residual pre-break ({wais_year[_pre][0]:.0f}-{wais_year[_pre][-1]:.0f}): '
      f'{_resid_mm[_pre].mean():+.2f} mm')
print(f'Mean residual post-break ({wais_year[_post][0]:.0f}-{wais_year[_post][-1]:.0f}): '
      f'{_resid_mm[_post].mean():+.2f} mm')
# Out:
# Correlation-aware level-space intervals (n=29, anchor year=1999.5, point estimate = MAP, not refit)
#   MAP/posterior-median ratio: b=1.00  c=1.00
#   b = 0.0148 mm/yr/degC
#       naive (independent-error) 90% halfwidth  = 0.0037 mm
#       robust (correlation-aware) 90% halfwidth = 0.0056 mm   (x1.50 vs naive)
#       published MCMC std = 0.0024 mm   (robust is x1.44 of published)
#   c = 0.1559 mm/yr
#       naive (independent-error) 90% halfwidth  = 0.0190 mm
#       robust (correlation-aware) 90% halfwidth = 0.0200 mm   (x1.05 vs naive)
#       published MCMC std = 0.0123 mm   (robust is x0.99 of published)
# Bayesian fit: acceleration a = 0.0148 mm/yr^2, velocity v = 0.1554 mm/yr
# S1_QUADRATIC_MEAN (a, v, H0) = array([1.47768168e-05, 1.55882653e-04, 1.24415552e-05])
# S1_QUADRATIC_COV =
# array([[1.16388500e-11, 1.23377108e-11, 3.74423171e-10],
#        [1.23377108e-11, 1.48410280e-10, 4.53077008e-09],
#        [3.74423171e-10, 4.53077008e-09, 1.38318903e-07]])
# ...

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Panel A: Observations + Bayesian quadratic-in-time fit (diagnostic)
ax = axes[0]
ax.errorbar(wais_year, wais_rebase * M_TO_MM, yerr=2 * wais_sigma * M_TO_MM,
            fmt='o', ms=6, color=COMP_COLORS['WAIS'], lw=1.5, alpha=0.6,
            label='Observations (IMBIE)')
ax.plot(_t_grid, _wais_bayes_p50, 'k-', lw=2, label='Bayesian quadratic fit (diagnostic)')
ax.fill_between(_t_grid, _wais_bayes_lo, _wais_bayes_hi, color='gray', alpha=0.2)
ax.axvline(WAIS_ONSET_YEAR, color='red', ls='--', lw=1.5, alpha=0.7,
           label=f'Structural break ~{WAIS_ONSET_YEAR:.0f}')
ax.set_xlabel('Year')
ax.set_ylabel('WAIS SLR (mm, 2000 baseline)')
ax.set_title('WAIS: descriptive quadratic-in-time fit')
ax.legend(fontsize=9)
ax.grid(True, alpha=0.2)

# Panel B: Rate evolution
ax = axes[1]
from component_analysis import compute_component_rates
rates = compute_component_rates(wais_year, wais_rebase, window=2)
valid = np.isfinite(rates)
ax.plot(wais_year[valid], rates[valid] * M_TO_MM, 'o-', ms=4, color=COMP_COLORS['WAIS'], lw=1.5)
ax.axvline(WAIS_ONSET_YEAR, color='red', ls='--', lw=1.5, alpha=0.7,
           label=f'~{WAIS_ONSET_YEAR:.0f} break')
ax.axhline(0, color='k', lw=0.5, ls='--')
ax.set_xlabel('Year')
ax.set_ylabel('WAIS rate (mm/yr)')
ax.set_title('WAIS rate evolution')
ax.legend(fontsize=9)
ax.grid(True, alpha=0.2)

plt.tight_layout()
plt.savefig(f'{FIG_DIR}/component_wais_observations.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 4. Projections

# %%
PROJ_YEARS = np.arange(1950, 2151, dtype=float)
PROJ_SSPS = ['SSP1-2.6', 'SSP2-4.5', 'SSP3-7.0', 'SSP5-8.5']
rng_wais = np.random.default_rng(2026)

# ── Observational anchor ──
anchor_year = wais_year[-1]
anchor_value_mm = wais_rebase[-1] * M_TO_MM
anchor_sigma_mm = wais_sigma[-1] * M_TO_MM
print(f'Anchor: year={anchor_year:.0f}, '
      f'IMBIE={anchor_value_mm:.1f} \u00b1 {anchor_sigma_mm:.1f} mm (1\u03c3)')

# ── Draw coherent trajectories (returns meters) ──
wais_samples_m, wais_params = sample_a4_wais_trajectories(
    N_SAMPLES, rng_wais, PROJ_YEARS,
    rheology_mode=RHEOLOGY_MODE,
    anchor_year=anchor_year,
    anchor_value_mm=anchor_value_mm,
    anchor_sigma_mm=anchor_sigma_mm,
    obs_years=wais_year,
    obs_values_mm=wais_rebase * M_TO_MM,
    obs_sigmas_mm=wais_sigma * M_TO_MM,
)

# Build projection dict (same for all SSPs -- A4 is SSP-independent)
# Each SSP gets its own copy to prevent accidental cross-SSP mutation.
wais_proj = {}
for ssp in PROJ_SSPS:
    wais_proj[ssp] = {
        'samples': wais_samples_m.copy(),
        'median': np.median(wais_samples_m, axis=0),
        'p5': np.percentile(wais_samples_m, 5, axis=0),
        'p95': np.percentile(wais_samples_m, 95, axis=0),
        'p17': np.percentile(wais_samples_m, 17, axis=0),
        'p83': np.percentile(wais_samples_m, 83, axis=0),
    }

# Report
idx_anchor = np.argmin(np.abs(PROJ_YEARS - anchor_year))
idx_2100 = np.argmin(np.abs(PROJ_YEARS - 2100))
med_anchor = np.median(wais_samples_m[:, idx_anchor])
sig_anchor = np.std(wais_samples_m[:, idx_anchor])
med = np.median(wais_samples_m[:, idx_2100])
p5 = np.percentile(wais_samples_m[:, idx_2100], 5)
p95 = np.percentile(wais_samples_m[:, idx_2100], 95)
print(f'WAIS at {anchor_year:.0f}: {med_anchor*M_TO_MM:.1f} \u00b1 {sig_anchor*M_TO_MM:.1f} mm '
      f'(IMBIE: {anchor_value_mm:.1f} \u00b1 {anchor_sigma_mm:.1f} mm)')
print(f'WAIS at 2100 (A4): {med:.2f} [{p5:.2f}, {p95:.2f}] m (SSP-independent)')

# Per-sample parameter summary
scenario_names = list(A4_SCENARIOS.keys())
for i, sn in enumerate(scenario_names):
    n_in = (wais_params['scenario_idx'] == i).sum()
    print(f'  {sn}: {n_in} samples ({n_in/N_SAMPLES:.0%})')
# 'beta' is S2's pre-blend power-law target shape; the realized post-anchor
# trajectory rate-space blends this with the quadratic near the anchor year
# (see cell 0 "S2 trajectory") and is instead summarized by
# wais_params['beta_eff_2035']/['beta_eff_2050'].
print(f'  Median beta: {np.median(wais_params["beta"]):.2f}')
# Out:
# Anchor: year=2020, IMBIE=5.8 ± 0.7 mm (1σ)
# WAIS at 2020: 5.7 ± 0.7 mm (IMBIE: 5.8 ± 0.7 mm)
# WAIS at 2100 (A4): 0.30 [0.07, 1.17] m (SSP-independent)
#   S1_status_quo: 2447 samples (24%)
#   S2_fast_wais: 7553 samples (76%)
#   Median beta: 2.06

# %%
# ── S1-only WAIS (no MISI): stable ice sheet scenario ──
# Override scenario weights to 100% S1, keeping everything else identical.
_saved_probs = {s: A4_SCENARIOS[s]['P'] for s in A4_SCENARIOS}
for s in A4_SCENARIOS:
    A4_SCENARIOS[s]['P'] = 1.0 if s == 'S1_status_quo' else 0.0

rng_s1 = np.random.default_rng(2026)
wais_s1_m, wais_s1_params = sample_a4_wais_trajectories(
    N_SAMPLES, rng_s1, PROJ_YEARS,
    rheology_mode=RHEOLOGY_MODE,
    anchor_year=anchor_year,
    anchor_value_mm=anchor_value_mm,
    anchor_sigma_mm=anchor_sigma_mm,
    obs_years=wais_year,
    obs_values_mm=wais_rebase * M_TO_MM,
    obs_sigmas_mm=wais_sigma * M_TO_MM,
)

# Restore original weights
for s in A4_SCENARIOS:
    A4_SCENARIOS[s]['P'] = _saved_probs[s]

# Report
med_s1 = np.median(wais_s1_m[:, idx_2100])
p5_s1 = np.percentile(wais_s1_m[:, idx_2100], 5)
p95_s1 = np.percentile(wais_s1_m[:, idx_2100], 95)
print(f'WAIS S1 (no MISI) at 2100: {med_s1:.3f} [{p5_s1:.3f}, {p95_s1:.3f}] m')
print(f'WAIS full mixture at 2100: {med:.3f} [{p5:.3f}, {p95:.3f}] m')
# Out:
# WAIS S1 (no MISI) at 2100: 0.089 [0.061, 0.117] m
# WAIS full mixture at 2100: 0.297 [0.075, 1.172] m

# %%
# WAIS has no temperature dependence — show obs + forward projection
# Total WAIS volume above flotation ~3.3 m SLE (Morlighem et al. 2020, BedMachine v3)
WAIS_VAF_M = 3.3

fig, ax = plt.subplots(figsize=(10, 5))

# Observations
ax.errorbar(wais_year, wais_rebase, yerr=2*wais_sigma,
            fmt='o', ms=4, color='#444444', lw=1, label='IMBIE observed', zorder=5)

# Projections (SSP-independent, show as single fan)
proj_mask = PROJ_YEARS >= BASELINE_YEAR
yr_plot = PROJ_YEARS[proj_mask]
p = wais_proj['SSP2-4.5']
ax.plot(yr_plot, p['median'][proj_mask], color=COMP_COLORS['WAIS'], lw=2,
        label='A4 projection (median)')
ax.fill_between(yr_plot, p['p17'][proj_mask],
                np.minimum(p['p83'][proj_mask], WAIS_VAF_M),
                color=COMP_COLORS['WAIS'], alpha=0.25, label='66% CI')
ax.fill_between(yr_plot, p['p5'][proj_mask],
                np.minimum(p['p95'][proj_mask], WAIS_VAF_M),
                color=COMP_COLORS['WAIS'], alpha=0.10, label='90% CI')

# Physical cap
ax.axhline(WAIS_VAF_M, color='k', ls=':', lw=1.5, alpha=0.6,
           label=f'WAIS $V_{{af}}$ = {WAIS_VAF_M} m')

ax.set_xlabel('Year')
ax.set_ylabel('WAIS SLR (m)')
ax.set_title('WAIS \u2014 A4 Projections (SSP-independent)')
ax.legend(fontsize=8, loc='upper left')
ax.set_xlim(1990, 2150)
ax.axhline(0, color='k', lw=0.5, ls='--')
ax.grid(True, alpha=0.2)

plt.tight_layout()
plt.savefig(f'{FIG_DIR}/component_wais_projection.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 5. IPCC Comparison
#
# The IPCC AR6 AIS component combines EAIS + Peninsula + WAIS. Our scenario-mixture framework
# produces wider uncertainty ranges than the IPCC medium-confidence AIS, reflecting
# the deep uncertainty in marine ice sheet instability that process models
# (ISMIP6) may underestimate.

# %%
fig, ax = plt.subplots(figsize=(10, 6))
proj_mask = PROJ_YEARS >= 2005
yr_plot = PROJ_YEARS[proj_mask]

# Our WAIS
p = wais_proj['SSP2-4.5']
ax.plot(yr_plot, p['median'][proj_mask], color=COMP_COLORS['WAIS'], lw=2,
        label='WAIS (A4, this study)')
ax.fill_between(yr_plot, p['p5'][proj_mask], p['p95'][proj_mask],
                color=COMP_COLORS['WAIS'], alpha=0.15)

# IPCC total AIS
for ssp, ssp_code in [('SSP2-4.5', 'ssp245'), ('SSP5-8.5', 'ssp585')]:
    ipcc = read_ipcc_component_nc(CONF_BASE, 'medium_confidence', ssp_code, 'AIS')
    if ipcc is not None:
        ex = ipcc_extract(ipcc)
        color = SSP_COLORS.get(ssp, 'gray')
        ax.plot(ex['years'], ex['q50'] / M_TO_MM, color=color, ls='--', lw=1.5,
                label=f'IPCC total AIS ({ssp})')
        ax.fill_between(ex['years'], ex['q05'] / M_TO_MM, ex['q95'] / M_TO_MM,
                        color=color, alpha=0.05)

ax.set_xlabel('Year')
ax.set_ylabel('SLR contribution (m)')
ax.set_title('WAIS A4 vs IPCC Total AIS')
ax.legend(fontsize=8)
ax.set_xlim(2005, 2150)
ax.axhline(0, color='k', lw=0.5, ls='--')
ax.grid(True, alpha=0.2)

plt.tight_layout()
plt.savefig(f'{FIG_DIR}/component_wais_ipcc_comparison.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 6. Appendix: Sensitivity
#
# ### Scenario weight sensitivity
# ### S2 upper-bound (95th percentile) sensitivity
# ### Range sensitivity
# ### Rheology exponent sensitivity

# %%
# ── Scenario-weight sensitivity: 1-D sweep of p(S1_status_quo) ──
# With only 2 scenarios, a tornado diagram (perturb one weight, read off the
# shift) is degenerate: perturbing p(S1) fully determines p(S2_fast_wais) =
# 1 - p(S1), so there is only one independent weight to vary. We instead
# sweep p(S1) over a plausible range and show the resulting median and 95th
# percentile directly, with the baseline (p(S1)=0.10) marked.
#
# We additionally test sensitivity to the S2_fast_wais skewness parameter
# alpha, alongside the weight sweep, comparing the current value (alpha=3)
# against two alternatives spanning the physically reasonable range:
#   - alpha=0: symmetric log-normal (no skew) -- the natural "no assumption"
#     baseline for the shape parameter.
#   - alpha=4: an upper literature value for MISI's flux-nonlinearity
#     amplification (Robel et al. 2019).
N_SENS = 100_000
p_s1_range = np.linspace(0.0, 0.50, 51)
baseline_p_s1 = A4_SCENARIOS['S1_status_quo']['P']
baseline_alpha = A4_SCENARIOS['S2_fast_wais']['alpha']
baseline_high_mm_m = A4_SCENARIOS['S2_fast_wais']['high_mm'] / M_TO_MM

alpha_values = [0.0, baseline_alpha, 4.0]
alpha_labels = {0.0: 'alpha = 0 (symmetric)',
                baseline_alpha: f'alpha = {baseline_alpha:.2f} (current)',
                4.0: 'alpha = 4 (upper literature value)'}
alpha_colors = {0.0: 'tab:orange', baseline_alpha: 'C0', 4.0: 'tab:green'}

medians = {a: np.zeros_like(p_s1_range) for a in alpha_values}
p95s = {a: np.zeros_like(p_s1_range) for a in alpha_values}
for i, p_s1 in enumerate(p_s1_range):
    weights = {'S1_status_quo': p_s1, 'S2_fast_wais': 1.0 - p_s1}
    for a in alpha_values:
        samples = sample_a4_wais_endpoint(
            N_SENS, np.random.default_rng(1000 + i),
            rheology_mode=RHEOLOGY_MODE,
            scenario_overrides={'S2_fast_wais': {'alpha': a}, 'weights': weights},
        )
        medians[a][i] = np.median(samples)
        p95s[a][i] = np.percentile(samples, 95)

# ── Cubic-in-p(S1) x quadratic-in-alpha: stat ~ cubic(p) x quadratic(alpha) ──
# stat ~ sum over i in {0..3}, j in {0,1,2} of b_ij * p(S1)^i * alpha^j (12 terms).
# Upgraded from the biquadratic (quadratic-in-both, 9-term) fit used
# previously (median R^2=0.995). A true bicubic (also cubic-in-alpha) was
# considered and rejected: alpha only takes 3 distinct values (0, 3, 4) in
# this sweep, so alpha^3 is an exact linear combination of {1, alpha,
# alpha^2} at those points -- the design matrix for a full bicubic is
# rank-deficient (verified: rank 12/16, not 16/16), meaning lstsq would
# return a minimum-norm solution with arbitrary, non-unique alpha^3-related
# coefficients despite an unchanged-looking R^2. Quadratic is the actual
# ceiling for alpha; there's no 4th alpha value to identify a cubic term
# against. Cubic-in-p(S1), by contrast, is well supported (51 distinct
# p(S1) values) and buys a real improvement: R^2 0.995 -> 0.999 on the
# median (verified against this exact data before choosing this form).
# The matrix_rank check below guards against silently fitting a
# rank-deficient model if this cell is ever extended further.
def fit_cubic_p_quad_alpha(vals_dict):
    p_fit = np.repeat(p_s1_range, len(alpha_values))
    a_fit = np.tile(alpha_values, len(p_s1_range))
    v_fit = np.concatenate([[vals_dict[a][i] for a in alpha_values]
                             for i in range(len(p_s1_range))])
    p_powers = [np.ones_like(p_fit), p_fit, p_fit**2, p_fit**3]
    a_powers = [np.ones_like(a_fit), a_fit, a_fit**2]
    X_fit = np.column_stack([pp * ap for pp in p_powers for ap in a_powers])
    rank = np.linalg.matrix_rank(X_fit)
    assert rank == X_fit.shape[1], (
        f'Design matrix is rank-deficient ({rank}/{X_fit.shape[1]}) -- '
        'fit would be non-unique; reduce the polynomial degree.')
    coef, *_ = np.linalg.lstsq(X_fit, v_fit, rcond=None)
    v_pred = X_fit @ coef
    r2 = 1 - np.sum((v_fit - v_pred)**2) / np.sum((v_fit - v_fit.mean())**2)
    return coef, r2

def cubic_p_quad_alpha_model(coef, p, a):
    p = np.asarray(p, dtype=float)
    a = np.asarray(a, dtype=float)
    p_powers = [np.ones_like(p), p, p**2, p**3]
    a_powers = [np.ones_like(a), a, a**2]
    terms = [pp * ap for pp in p_powers for ap in a_powers]
    return sum(c * t for c, t in zip(coef, terms))

med_coef, r2_med = fit_cubic_p_quad_alpha(medians)
p95_coef, r2_p95 = fit_cubic_p_quad_alpha(p95s)
_fit_term_labels_w = ['1', 'alpha', 'alpha^2', 'p', 'p alpha', 'p alpha^2',
                       'p^2', 'p^2 alpha', 'p^2 alpha^2',
                       'p^3', 'p^3 alpha', 'p^3 alpha^2']
print('Median fit [cubic(p) x quadratic(alpha)]: median ~ ' +
      ' '.join(f'{c:+.5g}*{lbl}' for c, lbl in zip(med_coef, _fit_term_labels_w)) +
      f'   [R^2={r2_med:.3f}]')
print('P95 fit    [cubic(p) x quadratic(alpha)]: p95    ~ ' +
      ' '.join(f'{c:+.5g}*{lbl}' for c, lbl in zip(p95_coef, _fit_term_labels_w)) +
      f'   [R^2={r2_p95:.3f}]')

# Font sizes matched to component_greenland_discharge_delay_fit.png
# (component_greenland.ipynb cell 10), which keeps arete_mpl's 'poster'
# style rather than this notebook's cell-1 rcParams shrink-down.
LEGEND_FONTSIZE = 12
TICK_FONTSIZE = 12
LABEL_FONTSIZE = 14
ANNOT_FONTSIZE = 10

fig, (ax_med, ax_p95) = plt.subplots(1, 2, figsize=(13, 5.5))

for ax, vals_dict, ylabel in [(ax_med, medians, 'Median WAIS SLR at 2100 (m)'),
                               (ax_p95, p95s, '95th-percentile WAIS SLR at 2100 (m)')]:
    for a in alpha_values:
        ax.plot(p_s1_range * 100, vals_dict[a], color=alpha_colors[a], lw=2,
                label=alpha_labels[a])
    baseline_val = np.interp(baseline_p_s1, p_s1_range, vals_dict[baseline_alpha])
    ax.axvline(baseline_p_s1 * 100, color='k', ls='--', lw=1)
    ax.scatter([baseline_p_s1 * 100], [baseline_val], color='k', zorder=5,
               label=f'Baseline: p(S1)={baseline_p_s1:.0%}, alpha={baseline_alpha:.2f}, '
                     f'value={baseline_val:.2f} m')
    ax.set_xlabel('p(S1_status_quo) (%)', fontsize=LABEL_FONTSIZE)
    ax.set_ylabel(ylabel, fontsize=LABEL_FONTSIZE)
    ax.grid(True, alpha=0.2)
    ax.tick_params(labelsize=TICK_FONTSIZE)

for a in alpha_values:
    ax_med.plot(p_s1_range * 100, cubic_p_quad_alpha_model(med_coef, p_s1_range, a),
                color=alpha_colors[a], lw=1.2, ls=':', alpha=0.8)
    ax_p95.plot(p_s1_range * 100, cubic_p_quad_alpha_model(p95_coef, p_s1_range, a),
                color=alpha_colors[a], lw=1.2, ls=':', alpha=0.8)
ax_med.plot([], [], color='0.3', lw=1.2, ls=':', alpha=0.8,
            label=f'Fit: cubic(p(S1)) x quadratic(alpha), R$^2$={r2_med:.3f}')
ax_p95.plot([], [], color='0.3', lw=1.2, ls=':', alpha=0.8,
            label=f'Fit: cubic(p(S1)) x quadratic(alpha), R$^2$={r2_p95:.3f}')

# Full 12-term formula is too long to display in-figure -- printed to stdout
# above instead; the in-figure note just names the fit form and R^2.
ax_med.text(0.02, 0.03,
            'median $\\approx$ cubic(p(S1)) x quadratic(alpha) -- see printed fit above'
            f'\n(p as fraction 0-0.50; R$^2$={r2_med:.3f}; approximation, not exact)',
            transform=ax_med.transAxes, fontsize=ANNOT_FONTSIZE, va='bottom', ha='left',
            bbox=dict(boxstyle='round', fc='white', ec='0.7', alpha=0.85))
ax_p95.text(0.02, 0.03,
            'p95 $\\approx$ cubic(p(S1)) x quadratic(alpha) -- see printed fit above'
            f'\n(p as fraction 0-0.50; R$^2$={r2_p95:.3f}; approximation, not exact)',
            transform=ax_p95.transAxes, fontsize=ANNOT_FONTSIZE, va='bottom', ha='left',
            bbox=dict(boxstyle='round', fc='white', ec='0.7', alpha=0.85))

ax_med.legend(fontsize=LEGEND_FONTSIZE, loc='upper right')
ax_p95.legend(fontsize=LEGEND_FONTSIZE, loc='upper right')

# ── Secondary y-axis: p95 / high_mm ──
# The mixture's p95 is set almost entirely by S2_fast_wais's own high_mm
# bound (its within-scenario p95 is fixed at high_mm by construction,
# independent of alpha -- see component_wais_s2_bound_sensitivity.png),
# so p95 rescales close to linearly with a different choice of high_mm.
# The median does NOT share this property (S1's fixed-scale contribution
# and low_mm's independent pinning break the proportionality -- median/h
# varies by up to ~2x over high_mm in [500, 1500] mm; see the same
# sensitivity figure), so only the p95 panel gets this secondary axis.
# The ratio is exact only at the baseline high_mm; checked against a
# direct (p(S1), alpha, high_mm) grid, it holds to within ~2-4% over
# p(S1) in [0, 10]% and degrades to ~6-9% by p(S1)=30% (S1's weight
# dilutes the S2-anchoring that makes p95 proportional to high_mm) --
# not re-verified out to the extended 50% upper end of this sweep, so
# treat the secondary axis as increasingly approximate there.
ax_p95_twin = ax_p95.twinx()
ax_p95_twin.set_ylim(np.array(ax_p95.get_ylim()) / baseline_high_mm_m)
ax_p95_twin.set_ylabel(f'p95 / high_mm (baseline high_mm={baseline_high_mm_m*M_TO_MM:.0f} mm)',
                        fontsize=LABEL_FONTSIZE - 2)
ax_p95_twin.tick_params(labelsize=TICK_FONTSIZE)

fig.suptitle('Scenario-weight and skewness sensitivity: p(S1) swept 0-50%, '
             '3 alpha choices for S2_fast_wais', fontsize=LABEL_FONTSIZE)
plt.tight_layout()
plt.savefig(f'{FIG_DIR}/component_wais_weight_sensitivity.png', dpi=150, bbox_inches='tight')
plt.show()
# Out:
# Median fit [cubic(p) x quadratic(alpha)]: median ~ +0.47346*1 -0.039653*alpha +0.0031154*alpha^2 -0.53098*p +0.044015*p alpha -0.0035313*p alpha^2 +0.981*p^2 -0.033184*p^2 alpha -0.005459*p^2 alpha^2 -2.5784*p^3 +0.23408*p^3 alpha -0.0011153*p^3 alpha^2   [R^2=0.999]
# P95 fit    [cubic(p) x quadratic(alpha)]: p95    ~ +1.3203*1 -0.0038295*alpha +0.00037704*alpha^2 -0.3921*p -0.093516*p alpha +0.010464*p alpha^2 -0.2537*p^2 +0.18735*p^2 alpha -0.026464*p^2 alpha^2 -0.11044*p^3 -0.27611*p^3 alpha +0.037198*p^3 alpha^2   [R^2=0.995]

# %%
# ── S2 upper-bound (95th-percentile) sensitivity: p(S1) sweep, colored by high_mm ──
# Mirrors the p(S1)/alpha figure above (component_wais_weight_sensitivity.png)
# exactly, but swaps which S2_fast_wais parameter modulates line color: here
# alpha is held at its baseline value (3.0 -- its effect on this sweep is
# already characterized above) and S2_fast_wais's within-scenario 95th-
# percentile bound (high_mm) takes alpha's place as the color dimension.
# This directly shows the (p(S1), high_mm) interaction that neither figure
# could show on its own: the previous version of this figure (a pure
# high_mm sweep at fixed p(S1)=0.10, colored by alpha) could not show how
# the bound choice interacts with scenario weighting, and the weight
# figure above holds high_mm fixed throughout.
#
# high_mm choices: 500 mm (near S1's pinned floor of 130 mm plus margin),
# 1000 mm (current baseline -- see A4_SCENARIOS comment block in
# component_projections.py for its literature cross-checks: Morlighem
# et al. 2020 ASE V_af+spillover ~1100 mm, Bamber et al. 2019 WAIS p95 at
# +5C ~1190 mm, DeConto & Pollard 2016 most aggressive MICI 640-1140 mm
# total Antarctic), 1300 mm (the notebook's previous choice, pinned
# directly to the IPCC AR6 low-confidence AIS p95 under SSP5-8.5 before
# it was lowered -- see git history), and 1500 mm (upper bracket).
N_SENS_BOUND2 = 100_000
high_mm_choices = [500.0, 1000.0, 1300.0, 1500.0]
baseline_high_mm = A4_SCENARIOS['S2_fast_wais']['high_mm']

_bound_cmap = plt.cm.viridis
_bound_norm_vals = np.array(high_mm_choices)
_bound_norm = (_bound_norm_vals - _bound_norm_vals.min()) / (_bound_norm_vals.max() - _bound_norm_vals.min())
bound_colors = {h: _bound_cmap(0.85 - 0.75 * n) for h, n in zip(high_mm_choices, _bound_norm)}
bound_labels = {h: (f'high_mm = {h:.0f} mm (current)' if h == baseline_high_mm
                     else f'high_mm = {h:.0f} mm')
                for h in high_mm_choices}

medians_b = {h: np.zeros_like(p_s1_range) for h in high_mm_choices}
p95s_b = {h: np.zeros_like(p_s1_range) for h in high_mm_choices}
for i, p_s1 in enumerate(p_s1_range):
    weights = {'S1_status_quo': p_s1, 'S2_fast_wais': 1.0 - p_s1}
    for h in high_mm_choices:
        samples = sample_a4_wais_endpoint(
            N_SENS_BOUND2, np.random.default_rng(3000 + i),
            rheology_mode=RHEOLOGY_MODE,
            scenario_overrides={'S2_fast_wais': {'high_mm': h, 'alpha': baseline_alpha},
                                 'weights': weights},
        )
        medians_b[h][i] = np.median(samples)
        p95s_b[h][i] = np.percentile(samples, 95)

# ── Cubic-in-p(S1) x quadratic-in-high_mm: stat ~ cubic(p) x quadratic(h) ──
# stat ~ sum over i in {0..3}, j in {0,1,2} of b_ij * p(S1)^i * high_mm^j (12 terms).
# Upgraded from the biquadratic (quadratic-in-both, 9-term) fit used
# previously (median R^2=0.995). A true bicubic (also cubic-in-high_mm)
# was considered and rejected: high_mm only has 4 distinct values in this
# sweep, so a cubic term is at best exactly-interpolating (zero degrees of
# freedom left to check it) and in practice numerically unstable here --
# high_mm's raw magnitude (up to 1500 mm, so high_mm^3 ~ 3.4e9) makes the
# unnormalized polynomial basis ill-conditioned enough that
# matrix_rank drops (verified: 15/16 for the full bicubic, not a clean
# rank deficiency like alpha's but not trustworthy either). Quadratic is
# the defensible ceiling for high_mm. Cubic-in-p(S1), by contrast, is
# well supported (51 distinct p(S1) values) and buys a real improvement:
# R^2 0.995 -> 0.998 on the median (verified against this exact data
# before choosing this form). The matrix_rank check below guards against
# silently fitting a rank-deficient model if this cell is ever extended.
def fit_cubic_p_quad_h(vals_dict):
    p_fit = np.repeat(p_s1_range, len(high_mm_choices))
    h_fit = np.tile(high_mm_choices, len(p_s1_range))
    v_fit = np.concatenate([[vals_dict[h][i] for h in high_mm_choices]
                             for i in range(len(p_s1_range))])
    p_powers = [np.ones_like(p_fit), p_fit, p_fit**2, p_fit**3]
    h_powers = [np.ones_like(h_fit), h_fit, h_fit**2]
    X_fit = np.column_stack([pp * hp for pp in p_powers for hp in h_powers])
    rank = np.linalg.matrix_rank(X_fit)
    assert rank == X_fit.shape[1], (
        f'Design matrix is rank-deficient ({rank}/{X_fit.shape[1]}) -- '
        'fit would be non-unique; reduce the polynomial degree.')
    coef, *_ = np.linalg.lstsq(X_fit, v_fit, rcond=None)
    v_pred = X_fit @ coef
    r2 = 1 - np.sum((v_fit - v_pred)**2) / np.sum((v_fit - v_fit.mean())**2)
    return coef, r2

def cubic_p_quad_h_model(coef, p, h):
    p = np.asarray(p, dtype=float)
    h = np.asarray(h, dtype=float)
    p_powers = [np.ones_like(p), p, p**2, p**3]
    h_powers = [np.ones_like(h), h, h**2]
    terms = [pp * hp for pp in p_powers for hp in h_powers]
    return sum(c * t for c, t in zip(coef, terms))

med_coef_b, r2_med_b = fit_cubic_p_quad_h(medians_b)
p95_coef_b, r2_p95_b = fit_cubic_p_quad_h(p95s_b)
_fit_term_labels = ['1', 'h', 'h^2', 'p', 'p h', 'p h^2', 'p^2', 'p^2 h', 'p^2 h^2',
                     'p^3', 'p^3 h', 'p^3 h^2']
print('Median fit [cubic(p) x quadratic(h)]: median ~ ' +
      ' '.join(f'{c:+.5g}*{lbl}' for c, lbl in zip(med_coef_b, _fit_term_labels)) +
      f'   [R^2={r2_med_b:.3f}]')
print('P95 fit    [cubic(p) x quadratic(h)]: p95    ~ ' +
      ' '.join(f'{c:+.5g}*{lbl}' for c, lbl in zip(p95_coef_b, _fit_term_labels)) +
      f'   [R^2={r2_p95_b:.3f}]')

fig_b, (ax_med_b, ax_p95_b) = plt.subplots(1, 2, figsize=(13, 5.5))

for ax, vals_dict, ylabel in [(ax_med_b, medians_b, 'Median WAIS SLR at 2100 (m)'),
                               (ax_p95_b, p95s_b, '95th-percentile WAIS SLR at 2100 (m)')]:
    for h in high_mm_choices:
        ax.plot(p_s1_range * 100, vals_dict[h], color=bound_colors[h], lw=2,
                label=bound_labels[h])
    baseline_val_b = np.interp(baseline_p_s1, p_s1_range, vals_dict[baseline_high_mm])
    ax.axvline(baseline_p_s1 * 100, color='k', ls='--', lw=1)
    ax.scatter([baseline_p_s1 * 100], [baseline_val_b], color='k', zorder=5,
               label=f'Baseline: p(S1)={baseline_p_s1:.0%}, high_mm={baseline_high_mm:.0f} mm, '
                     f'value={baseline_val_b:.2f} m')
    ax.set_xlabel('p(S1_status_quo) (%)', fontsize=LABEL_FONTSIZE)
    ax.set_ylabel(ylabel, fontsize=LABEL_FONTSIZE)
    ax.grid(True, alpha=0.2)
    ax.tick_params(labelsize=TICK_FONTSIZE)

for h in high_mm_choices:
    ax_med_b.plot(p_s1_range * 100, cubic_p_quad_h_model(med_coef_b, p_s1_range, h),
                  color=bound_colors[h], lw=1.2, ls=':', alpha=0.8)
    ax_p95_b.plot(p_s1_range * 100, cubic_p_quad_h_model(p95_coef_b, p_s1_range, h),
                  color=bound_colors[h], lw=1.2, ls=':', alpha=0.8)
ax_med_b.plot([], [], color='0.3', lw=1.2, ls=':', alpha=0.8,
              label=f'Fit: cubic(p(S1)) x quadratic(high_mm), R$^2$={r2_med_b:.3f}')
ax_p95_b.plot([], [], color='0.3', lw=1.2, ls=':', alpha=0.8,
              label=f'Fit: cubic(p(S1)) x quadratic(high_mm), R$^2$={r2_p95_b:.3f}')

# Full 12-term formula is too long to display in-figure -- printed to stdout
# above instead; the in-figure note just names the fit form and R^2.
ax_med_b.text(0.02, 0.03,
              'median $\\approx$ cubic(p(S1)) x quadratic(high_mm) -- see printed fit above'
              f'\n(p as fraction 0-0.50, h = high_mm in mm; R$^2$={r2_med_b:.3f}; approximation, not exact)',
              transform=ax_med_b.transAxes, fontsize=ANNOT_FONTSIZE, va='bottom', ha='left',
              bbox=dict(boxstyle='round', fc='white', ec='0.7', alpha=0.85))
ax_p95_b.text(0.02, 0.03,
              'p95 $\\approx$ cubic(p(S1)) x quadratic(high_mm) -- see printed fit above'
              f'\n(p as fraction 0-0.50, h = high_mm in mm; R$^2$={r2_p95_b:.3f}; approximation, not exact)',
              transform=ax_p95_b.transAxes, fontsize=ANNOT_FONTSIZE, va='bottom', ha='left',
              bbox=dict(boxstyle='round', fc='white', ec='0.7', alpha=0.85))

ax_med_b.legend(fontsize=LEGEND_FONTSIZE - 1, loc='upper right')
ax_p95_b.legend(fontsize=LEGEND_FONTSIZE - 1, loc='upper right')

fig_b.suptitle('S2 upper-bound sensitivity: p(S1) swept 0-50%, '
               '4 high_mm choices for S2_fast_wais', fontsize=LABEL_FONTSIZE)
plt.tight_layout()
plt.savefig(f'{FIG_DIR}/component_wais_s2_bound_sensitivity.png', dpi=150, bbox_inches='tight')
plt.show()
# Out:
# Median fit [cubic(p) x quadratic(h)]: median ~ +0.17737*1 +0.00025399*h -4.9165e-08*h^2 -0.06343*p -0.00045179*p h +8.1469e-08*p h^2 +0.53247*p^2 +0.00047008*p^2 h -1.6013e-07*p^2 h^2 -0.99992*p^3 -0.0013036*p^3 h +4.2132e-07*p^3 h^2   [R^2=0.998]
# P95 fit    [cubic(p) x quadratic(h)]: p95    ~ +0.0037387*1 +0.0013104*h -5.1343e-09*h^2 +0.11645*p -0.00050727*p h -8.7617e-08*p h^2 +0.037873*p^2 -0.00032292*p^2 h -1.5328e-07*p^2 h^2 +0.046871*p^3 -0.00014334*p^3 h +2.0625e-07*p^3 h^2   [R^2=1.000]

# %%
# ── PROTOTYPE: joint (p(S1), high_mm) -> median WAIS SLR heatmap ──
# Draft figure for review, not yet folded into the appendix structure above.
# Shows the full joint sensitivity surface that neither line-sweep figure
# above can show on its own: median WAIS SLR at 2100 as a function of both
# p(S1) [0, 50%] and S2_fast_wais's high_mm bound [500, 1500 mm]
# simultaneously, at alpha held to its baseline (3.0) -- alpha's own effect
# is already characterized in the p(S1)/alpha figure above, and adding it
# here as a 4th dimension would overload one panel.
#
# Grid is 35x21 = 735 points, each needing its own MC draw, vs. the ~30-200
# draws used by the line sweeps above; N_HEATMAP is dropped accordingly
# (20k vs. 100k) to keep runtime reasonable. The resulting per-cell
# tail-quantile noise is visible as jitter in the contours -- acceptable
# here since the heatmap is meant to be read qualitatively (shape of the
# surface, where it's steep vs. flat), not off exact pixel values; the
# line-sweep figures above remain the source for precise numbers.
N_HEATMAP = 20_000
p1_grid = np.linspace(0.0, 0.50, 35)
high_mm_grid = np.linspace(500.0, 1500.0, 21)

Z_median = np.zeros((len(high_mm_grid), len(p1_grid)))
for i, p1 in enumerate(p1_grid):
    weights = {'S1_status_quo': p1, 'S2_fast_wais': 1.0 - p1}
    for j, h in enumerate(high_mm_grid):
        samples = sample_a4_wais_endpoint(
            N_HEATMAP, np.random.default_rng(4000 + i * len(high_mm_grid) + j),
            rheology_mode=RHEOLOGY_MODE,
            scenario_overrides={'S2_fast_wais': {'high_mm': h, 'alpha': baseline_alpha},
                                 'weights': weights},
        )
        Z_median[j, i] = np.median(samples)

P1_mesh, H_mesh = np.meshgrid(p1_grid * 100, high_mm_grid)

fig_hm, ax_hm = plt.subplots(figsize=(8, 6.5))
im_hm = ax_hm.contourf(P1_mesh, H_mesh, Z_median, levels=20, cmap='viridis')
cbar_hm = fig_hm.colorbar(im_hm, ax=ax_hm)
cbar_hm.set_label('Median WAIS SLR at 2100 (m)', fontsize=LABEL_FONTSIZE)

contour_levels = np.round(np.linspace(Z_median.min(), Z_median.max(), 5)[1:-1], 2)
cs_hm = ax_hm.contour(P1_mesh, H_mesh, Z_median, levels=contour_levels,
                       colors='white', linewidths=1.0)
ax_hm.clabel(cs_hm, inline=True, fontsize=ANNOT_FONTSIZE, fmt='%.2f m')

ax_hm.scatter([baseline_p_s1 * 100], [baseline_high_mm], marker='*', s=300,
              color='black', edgecolor='white', linewidth=1.2, zorder=5,
              label=f'Baseline: p(S1)={baseline_p_s1:.0%}, high_mm={baseline_high_mm:.0f} mm')
ax_hm.legend(fontsize=LEGEND_FONTSIZE, loc='upper right')

ax_hm.set_xlabel('p(S1_status_quo) (%)', fontsize=LABEL_FONTSIZE)
ax_hm.set_ylabel('S2_fast_wais upper bound (95th percentile, mm)', fontsize=LABEL_FONTSIZE)
ax_hm.tick_params(labelsize=TICK_FONTSIZE)
ax_hm.set_title('Median WAIS SLR at 2100: joint (p(S1), high_mm) sensitivity\n'
                 f'(alpha = {baseline_alpha:.2f}, N={N_HEATMAP:,} per grid point)',
                 fontsize=LABEL_FONTSIZE)

plt.tight_layout()
plt.savefig(f'{FIG_DIR}/component_wais_median_heatmap_prototype.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# ── Scenario-weight sensitivity: PDF (a) and projection fan (b) ──
# Compares the published result (n ~ N(4.1, 0.4^2), 10/90 baseline weighting)
# against three n=3-fixed (no rheology correction) cases at different
# S1/S2_fast_wais weightings -- 10/90 (baseline), 30/70, and 1/99 -- to show
# how the weighting alone reshapes both the endpoint PDF and the full
# projection fan, independent of the rheology correction. The
# n=3-fixed toggle (via N_OBS_MEAN/N_OBS_SIGMA below) only affects
# S2_fast_wais: S1_status_quo carries no rheology correction. This is a
# diagnostic only; it restores A4_SCENARIOS and the rheology constants to
# their original values afterward and does not modify any exported HDF5
# group.
import component_projections as _cproj_w
from scipy.stats import gaussian_kde as _kde_w

_N_OBS_MEAN_ORIG_w = _cproj_w.N_OBS_MEAN
_N_OBS_SIGMA_ORIG_w = _cproj_w.N_OBS_SIGMA
_P_ORIG_w = {s: A4_SCENARIOS[s]['P'] for s in A4_SCENARIOS}

_weight_cases_w = [
    ('current', False, 0.10),
    ('n3_1090', True, 0.10),
    ('n3_3070', True, 0.30),
    ('n3_0199', True, 0.01),
]

_mix_w = {}
_traj_w = {}
try:
    for key, n3_fixed, p_s1 in _weight_cases_w:
        if n3_fixed:
            _cproj_w.N_OBS_MEAN = 3.0
            _cproj_w.N_OBS_SIGMA = 0.0
        else:
            _cproj_w.N_OBS_MEAN = _N_OBS_MEAN_ORIG_w
            _cproj_w.N_OBS_SIGMA = _N_OBS_SIGMA_ORIG_w
        A4_SCENARIOS['S1_status_quo']['P'] = p_s1
        A4_SCENARIOS['S2_fast_wais']['P'] = 1.0 - p_s1

        _mix_w[key] = sample_a4_wais_endpoint(
            200_000, np.random.default_rng(99), rheology_mode=RHEOLOGY_MODE,
        )  # meters

        _samples_m, _ = sample_a4_wais_trajectories(
            N_SAMPLES, np.random.default_rng(2026), PROJ_YEARS,
            rheology_mode=RHEOLOGY_MODE,
            anchor_year=anchor_year, anchor_value_mm=anchor_value_mm,
            anchor_sigma_mm=anchor_sigma_mm,
            obs_years=wais_year, obs_values_mm=wais_rebase * M_TO_MM,
            obs_sigmas_mm=wais_sigma * M_TO_MM,
        )
        _traj_w[key] = _samples_m
finally:
    _cproj_w.N_OBS_MEAN = _N_OBS_MEAN_ORIG_w
    _cproj_w.N_OBS_SIGMA = _N_OBS_SIGMA_ORIG_w
    for _s, _p in _P_ORIG_w.items():
        A4_SCENARIOS[_s]['P'] = _p

_labels_w = {
    'current': 'Current (n ~ N(4.1, 0.4\u00b2), 10/90)',
    'n3_1090': 'n = 3 (fixed), 10/90 (baseline weighting)',
    'n3_3070': 'n = 3 (fixed), 30/70 weighting',
    'n3_0199': 'n = 3 (fixed), 1/99 weighting',
}
_colors_w = {'current': 'tab:blue', 'n3_1090': 'tab:gray',
             'n3_3070': 'tab:red', 'n3_0199': 'tab:purple'}
_ls_w = {'current': '-', 'n3_1090': '-', 'n3_3070': '--', 'n3_0199': '--'}

fig_w, (ax_w_pdf, ax_w_fan) = plt.subplots(1, 2, figsize=(14, 6))

# -- Panel (a): PDF at 2100 --
_x_w = np.linspace(0, 3.0, 600)  # meters
_dx_w = _x_w[1] - _x_w[0]
for key in _labels_w:
    _kde = _kde_w(_mix_w[key], bw_method='scott')
    _prob = _kde(_x_w) * _dx_w * 100
    ax_w_pdf.plot(_prob, _x_w, lw=2, color=_colors_w[key], ls=_ls_w[key],
                  label=_labels_w[key])
    if _ls_w[key] == '-':
        ax_w_pdf.fill_betweenx(_x_w, _prob, alpha=0.15, color=_colors_w[key])
ax_w_pdf.set_xlim(0, 2.0)
ax_w_pdf.set_ylim(0, 3.0)
ax_w_pdf.set_xlabel('Probability (%)')
ax_w_pdf.set_ylabel('WAIS SLR at 2100 (m)')
ax_w_pdf.legend(fontsize=9, loc='upper right')
ax_w_pdf.grid(True, alpha=0.2)
ax_w_pdf.set_title('(a) PDF at 2100')

# -- Panel (b): projection fan, median + 17-83% CI --
_proj_mask_w = PROJ_YEARS >= 2020
for key in _labels_w:
    _med_f = np.median(_traj_w[key], axis=0)  # meters
    _p17_f = np.percentile(_traj_w[key], 17, axis=0)  # meters
    _p83_f = np.percentile(_traj_w[key], 83, axis=0)  # meters
    ax_w_fan.plot(PROJ_YEARS[_proj_mask_w], _med_f[_proj_mask_w],
                  color=_colors_w[key], lw=2, ls=_ls_w[key], label=_labels_w[key])
    if _ls_w[key] == '-':
        ax_w_fan.fill_between(PROJ_YEARS[_proj_mask_w], _p17_f[_proj_mask_w],
                              _p83_f[_proj_mask_w], color=_colors_w[key], alpha=0.15)
ax_w_fan.set_xlim(1992, 2100)
ax_w_fan.set_ylim(-0.04, 1.0)
ax_w_fan.set_xlabel('Year')
ax_w_fan.set_ylabel('WAIS SLR (m)')
ax_w_fan.legend(fontsize=9, loc='upper left')
ax_w_fan.grid(True, alpha=0.2)
ax_w_fan.set_title('(b) Projection fan, median + 17-83% CI')

plt.tight_layout()
plt.savefig(f'{FIG_DIR}/component_wais_scenario_weight_pdf.png', dpi=150, bbox_inches='tight')
plt.show()
print('Saved component_wais_scenario_weight_pdf.png (2-panel)')
# Out:
# Saved component_wais_scenario_weight_pdf.png (2-panel)

# %%
# ── Skewness (alpha) sensitivity: PDF (a) and projection fan (b) ──
# Compares four choices of the S2_fast_wais skewness parameter alpha, at
# the baseline weighting (10/90) and published rheology mode
# (n ~ N(4.1, 0.4^2)):
#   alpha=0:    symmetric log-normal (no skew)
#   alpha=1.6:  intermediate value
#   alpha=3:    current
#   alpha=4:    upper literature value (Robel et al. 2019)
# This is a diagnostic only; it restores A4_SCENARIOS to its original
# value afterward and does not modify any exported HDF5 group.
from scipy.stats import gaussian_kde as _kde_a

alpha_test_values = [0.0, 1.6, 3.0, 4.0]
_alpha_orig_a = A4_SCENARIOS['S2_fast_wais']['alpha']

_mix_a = {}
_traj_a = {}
try:
    for a in alpha_test_values:
        A4_SCENARIOS['S2_fast_wais']['alpha'] = a

        _mix_a[a] = sample_a4_wais_endpoint(
            200_000, np.random.default_rng(99), rheology_mode=RHEOLOGY_MODE,
        )  # meters

        _samples_m, _ = sample_a4_wais_trajectories(
            N_SAMPLES, np.random.default_rng(2026), PROJ_YEARS,
            rheology_mode=RHEOLOGY_MODE,
            anchor_year=anchor_year, anchor_value_mm=anchor_value_mm,
            anchor_sigma_mm=anchor_sigma_mm,
            obs_years=wais_year, obs_values_mm=wais_rebase * M_TO_MM,
            obs_sigmas_mm=wais_sigma * M_TO_MM,
        )
        _traj_a[a] = _samples_m
finally:
    A4_SCENARIOS['S2_fast_wais']['alpha'] = _alpha_orig_a

_colors_a = {0.0: 'tab:orange', 1.6: 'tab:cyan', 3.0: 'C0', 4.0: 'tab:green'}
_labels_a = {0.0: 'alpha = 0 (symmetric)',
             1.6: 'alpha = 1.6',
             3.0: 'alpha = 3 (current)',
             4.0: 'alpha = 4 (upper literature value)'}

fig_a, (ax_a_pdf, ax_a_fan) = plt.subplots(1, 2, figsize=(14, 6))

# -- Panel (a): PDF at 2100 --
_x_a = np.linspace(0, 3.0, 600)  # meters
_dx_a = _x_a[1] - _x_a[0]
for a in alpha_test_values:
    _kde = _kde_a(_mix_a[a], bw_method='scott')
    _prob = _kde(_x_a) * _dx_a * 100
    ax_a_pdf.plot(_prob, _x_a, lw=2, color=_colors_a[a], label=_labels_a[a])
    ax_a_pdf.fill_betweenx(_x_a, _prob, alpha=0.10, color=_colors_a[a])
ax_a_pdf.set_xlim(0, 2.0)
ax_a_pdf.set_ylim(0, 3.0)
ax_a_pdf.set_xlabel('Probability (%)')
ax_a_pdf.set_ylabel('WAIS SLR at 2100 (m)')
ax_a_pdf.legend(fontsize=9, loc='upper right')
ax_a_pdf.grid(True, alpha=0.2)
ax_a_pdf.set_title('(a) PDF at 2100')

# -- Panel (b): projection fan, median + 17-83% CI --
_proj_mask_a = PROJ_YEARS >= 2020
for a in alpha_test_values:
    _med_f = np.median(_traj_a[a], axis=0)  # meters
    _p17_f = np.percentile(_traj_a[a], 17, axis=0)  # meters
    _p83_f = np.percentile(_traj_a[a], 83, axis=0)  # meters
    ax_a_fan.plot(PROJ_YEARS[_proj_mask_a], _med_f[_proj_mask_a], color=_colors_a[a],
                  lw=2, label=_labels_a[a])
    ax_a_fan.fill_between(PROJ_YEARS[_proj_mask_a], _p17_f[_proj_mask_a],
                          _p83_f[_proj_mask_a], color=_colors_a[a], alpha=0.10)
ax_a_fan.set_xlim(1992, 2100)
ax_a_fan.set_ylim(-0.04, 1.0)
ax_a_fan.set_xlabel('Year')
ax_a_fan.set_ylabel('WAIS SLR (m)')
ax_a_fan.legend(fontsize=9, loc='upper left')
ax_a_fan.grid(True, alpha=0.2)
ax_a_fan.set_title('(b) Projection fan, median + 17-83% CI')

plt.tight_layout()
plt.savefig(f'{FIG_DIR}/component_wais_alpha_sensitivity.png', dpi=150, bbox_inches='tight')
plt.show()
print('Saved component_wais_alpha_sensitivity.png')
# Out:
# Saved component_wais_alpha_sensitivity.png

# %% [markdown]
# ### Physically motivated weight alternatives
#
# The sweep above varies p(S1) continuously. Here we test complete, physically
# motivated weight combinations that represent distinct interpretive stances on
# WAIS dynamics. For each combination, we report the 5th, 50th, and 95th
# percentiles of the mixture distribution at 2100 (Mode B rheology).

# %%
# ── Physically motivated weight alternatives ──
N_WEIGHT_SENS = 100_000

weight_combos = {
    'Baseline (10/90)':       {'S1_status_quo': 0.10, 'S2_fast_wais': 0.90},
    'Conservative (20/80)':   {'S1_status_quo': 0.20, 'S2_fast_wais': 0.80},
    'Skeptical of MISI (30/70)': {'S1_status_quo': 0.30, 'S2_fast_wais': 0.70},
}

print(f'{"Weight combination":<30s}  {"p5 (m)":>8s}  {"p50 (m)":>8s}  {"p95 (m)":>8s}')
print('-' * 62)

for label, weights in weight_combos.items():
    assert abs(sum(weights.values()) - 1.0) < 1e-10, f'Weights do not sum to 1: {weights}'
    samples = sample_a4_wais_endpoint(
        N_WEIGHT_SENS, np.random.default_rng(314),
        rheology_mode='B',
        scenario_overrides={'weights': weights},
    )
    p5, p50, p95 = np.percentile(samples, [5, 50, 95])
    print(f'{label:<30s}  {p5:8.3f}  {p50:8.3f}  {p95:8.3f}')
# Out:
# Weight combination                p5 (m)   p50 (m)   p95 (m)
# --------------------------------------------------------------
# Baseline (10/90)                   0.089     0.349     1.262
# Conservative (20/80)               0.078     0.315     1.194
# Skeptical of MISI (30/70)          0.072     0.275     1.124

# %%
# ── Range sensitivity: ±20% on (low, high) bounds ──
# S1_status_quo is excluded: it is sampled directly from its
# quadratic-in-time posterior (S1_QUADRATIC_MEAN/_COV), not a
# low_mm/high_mm range, so a "±20% on bounds" perturbation has no
# analogue for S1. Only S2_fast_wais's bounds are perturbed here.
N_SENS = 100000

print('Range sensitivity (\u00b120% on S2_fast_wais bounds):')
for factor_label, range_factor in [('-20%', 0.8), ('Base', 1.0), ('+20%', 1.2)]:
    s2 = A4_SCENARIOS['S2_fast_wais']
    overrides = {'S2_fast_wais': {'low_mm': s2['low_mm'] * range_factor,
                                   'high_mm': s2['high_mm'] * range_factor}}
    samples = sample_a4_wais_endpoint(
        N_SENS, np.random.default_rng(77), rheology_mode=RHEOLOGY_MODE,
        scenario_overrides=overrides,
    )
    p5, med, p95 = np.percentile(samples, [5, 50, 95])
    print(f'  {factor_label}: median={med:.2f} [{p5:.2f}, {p95:.2f}] m')

# ── Rheology exponent sensitivity ──
print('\nRheology exponent sensitivity:')
for n_exp in [3.5, 4.0, 4.5]:
    rheo_med = 1 + RHEOLOGY_SENSITIVITY * (n_exp - N_REF)
    rng_rh = np.random.default_rng(88)
    scenarios = list(A4_SCENARIOS.keys())
    probs = [A4_SCENARIOS[s]['P'] for s in scenarios]
    samples_rh = np.zeros(N_SENS)
    scenario_idx = rng_rh.choice(len(scenarios), size=N_SENS, p=probs)
    child_rngs = rng_rh.spawn(len(scenarios))
    for k, sname in enumerate(scenarios):
        mask = scenario_idx == k
        n_s = mask.sum()
        if n_s == 0:
            continue
        crng = child_rngs[k]
        if sname == 'S1_status_quo':
            # No rheology correction for S1 (see A4_SCENARIOS comment
            # block): the n=3->n≈4 correction addresses ISMIP6-class
            # structural bias, which does not apply to a statistical fit
            # of observed mass balance.
            samples_rh[mask] = _sample_s1_quadratic_mm(n_s, crng, [2100.0])[:, 0]
            continue
        s = A4_SCENARIOS[sname]
        base_s = _sample_log_skewnormal(
            n_s, s['low_mm'], s['high_mm'], s['alpha'], crng,
        )
        rheo = crng.normal(rheo_med, RHEOLOGY_FACTOR_SIGMA, n_s)
        rheo = np.maximum(rheo, 1.0)
        base_s *= rheo
        samples_rh[mask] = base_s
    samples_rh /= M_TO_MM  # mm -> m
    p5, med, p95 = np.percentile(samples_rh, [5, 50, 95])
    print(f'  n={n_exp}: rheology factor={rheo_med:.2f}, '
          f'median={med:.2f} [{p5:.2f}, {p95:.2f}] m')

# ── Skewness sensitivity ──
print('\nSkewness (alpha) sensitivity for S2_fast_wais (baseline alpha=3):')
for alpha_test in [-3, 0, 3.0, 6]:
    overrides = {'S2_fast_wais': {'alpha': alpha_test}}
    samples = sample_a4_wais_endpoint(
        N_SENS, np.random.default_rng(55), rheology_mode=RHEOLOGY_MODE,
        scenario_overrides=overrides,
    )
    p5, med, p95 = np.percentile(samples, [5, 50, 95])
    print(f'  alpha={alpha_test}: median={med:.2f} [{p5:.2f}, {p95:.2f}] m')
# Out:
# Range sensitivity (±20% on S2_fast_wais bounds):
#   -20%: median=0.23 [0.07, 0.94] m
#   Base: median=0.29 [0.07, 1.17] m
#   +20%: median=0.35 [0.07, 1.40] m
#
# Rheology exponent sensitivity:
#   n=3.5: rheology factor=1.14, median=0.26 [0.07, 1.01] m
#   n=4.0: rheology factor=1.28, median=0.29 [0.07, 1.14] m
#   n=4.5: rheology factor=1.42, median=0.32 [0.07, 1.26] m
#
# Skewness (alpha) sensitivity for S2_fast_wais (baseline alpha=3):
#   alpha=-3: median=0.44 [0.07, 1.25] m
#   alpha=0: median=0.36 [0.07, 1.21] m
#   alpha=3.0: median=0.30 [0.07, 1.17] m
#   alpha=6: median=0.27 [0.07, 1.16] m

# %%
# ══════════════════════════════════════════════════════════════════
# §6  Export results to HDF5
# ══════════════════════════════════════════════════════════════════
from component_io import save_wais

# WAIS is SSP-independent: all SSPs share identical samples.
# Store full samples only for the first SSP; omit from the rest
# to avoid 4x redundant writes to HDF5.
wais_proj_lean = {}
for i, ssp in enumerate(PROJ_SSPS):
    proj_i = dict(wais_proj[ssp])  # shallow copy of the dict
    if i > 0:
        proj_i.pop('samples', None)  # omit redundant samples
    wais_proj_lean[ssp] = proj_i

save_wais(
    a4_scenarios=A4_SCENARIOS,
    obs_years=wais_year,
    obs_H=wais_rebase,
    obs_sigma=wais_sigma,
    wais_proj=wais_proj_lean,
    rheology_factor_median=RHEOLOGY_FACTOR_MEDIAN,
    rheology_factor_sigma=RHEOLOGY_FACTOR_SIGMA,
    rheology_mode=RHEOLOGY_MODE,
    wais_onset_year=WAIS_ONSET_YEAR,
)


# ── Save S1-only (stable WAIS) samples separately ──
# Save both the full 10k ensemble and a 2k downsampled version.
# The 2k version is used by component_forecast.ipynb for the
# stable-WAIS blended forecast, keeping sample sizes consistent
# across components.  Downsampling is done here (at the source)
# so the resampling logic lives with the WAIS code.
import h5py as _h5
from component_io import DEFAULT_H5_PATH
from slr_forecast.config import N_SAMPLES as N_SAMPLES_DEFAULT  # 2000

_rng_ds = np.random.default_rng(2026)

# Downsample to N_SAMPLES_DEFAULT if WAIS was generated with more samples.
# When N_SAMPLES == N_SAMPLES_DEFAULT (the current default), this is a no-op.
if wais_samples_m.shape[0] > N_SAMPLES_DEFAULT:
    _idx_full_ds = _rng_ds.choice(wais_samples_m.shape[0], size=N_SAMPLES_DEFAULT, replace=False)
    _idx_s1_ds = _rng_ds.choice(wais_s1_m.shape[0], size=N_SAMPLES_DEFAULT, replace=False)
    wais_full_2k = wais_samples_m[_idx_full_ds]
    wais_s1_2k = wais_s1_m[_idx_s1_ds]
    wais_scenario_idx_2k = wais_params['scenario_idx'][_idx_full_ds]
else:
    wais_full_2k = wais_samples_m
    wais_s1_2k = wais_s1_m
    wais_scenario_idx_2k = wais_params['scenario_idx']

with _h5.File(DEFAULT_H5_PATH, 'a') as hf:
    # ── S1 full (10k) ──
    if 'wais_s1' in hf:
        del hf['wais_s1']
    sg = hf.create_group('wais_s1')
    sg.attrs['description'] = (
        'S1 (no-MISI) WAIS projections: 100% weight on S1_status_quo scenario. '
        'Linear ramp, no marine ice-sheet instability.'
    )
    sg.attrs['scenario'] = 'S1_status_quo'
    sg.attrs['rheology_mode'] = RHEOLOGY_MODE
    sg.create_dataset('years', data=PROJ_YEARS)
    sg.create_dataset('samples', data=wais_s1_m, compression='gzip')
    sg.create_dataset('median', data=np.median(wais_s1_m, axis=0))
    sg.create_dataset('p5', data=np.percentile(wais_s1_m, 5, axis=0))
    sg.create_dataset('p95', data=np.percentile(wais_s1_m, 95, axis=0))

    # ── Downsampled (2k) versions for component_forecast ──
    if 'wais_2k' in hf:
        del hf['wais_2k']
    dg = hf.create_group('wais_2k')
    dg.attrs['description'] = (
        f'WAIS samples for component_forecast.ipynb ({N_SAMPLES_DEFAULT} samples). '
        f'Downsampled from {N_SAMPLES} if overridden, otherwise identical to full. '
        'Full mixture and S1-only.'
    )
    dg.attrs['n_full'] = N_SAMPLES
    dg.attrs['n_downsampled'] = N_SAMPLES_DEFAULT
    dg.create_dataset('years', data=PROJ_YEARS)
    dg.create_dataset('full_samples', data=wais_full_2k, compression='gzip')
    dg.create_dataset('s1_samples', data=wais_s1_2k, compression='gzip')
    # Per-sample A4 scenario membership for full_samples (0=S1_status_quo,
    # 1=S2_fast_wais), index-aligned with full_samples. Lets downstream code
    # (e.g. compute_evpi.py) condition directly on scenario membership
    # instead of a percentile-threshold proxy.
    dg.create_dataset('scenario_idx', data=wais_scenario_idx_2k)
    dg.attrs['scenario_names'] = list(A4_SCENARIOS.keys())

print(f'Saved wais_s1 samples: {wais_s1_m.shape}')
print(f'Saved wais_2k: full {wais_full_2k.shape}, s1 {wais_s1_2k.shape}')
# Out:
# Saved wais → /Users/minchew/Dropbox/Documents/Research/SLR/forecasting/global_simple_v1/slr_forecast/data/processed/component_results.h5  (684026 KB total)
# Saved wais_s1 samples: (10000, 201)
# Saved wais_2k: full (2000, 201), s1 (2000, 201)

# %% [markdown]
# ### Rheology correction sensitivity: n=3 (fixed) vs. published ($n \sim \mathcal{N}(4.1, 0.4^2)$)
#
# To quantify how much the rheology correction (Mode B: a single draw of the
# Glen's law exponent n drives both the endpoint multiplier R(n) and the
# trajectory exponent beta(n)) changes the results, we recompute the endpoint
# mixture and the full projection fan with n fixed at 3 (no distribution --
# R=1, beta=beta_ref identically, i.e. no correction at all) and compare
# against the published Mode B results. The same RNG seeds are used for both,
# so scenario assignment and the underlying skew-normal draws are identical
# between the two runs; only the n-dependent rheology terms differ. This is a
# diagnostic only -- it does not modify `A4_SCENARIOS`, `wais_samples_m`, or
# any exported HDF5 group.

# %%
# ── Rheology sensitivity: n=3 (fixed) vs. current n ~ N(4.1, 0.4^2) ──
import component_projections as _cproj

_N_OBS_MEAN_ORIG = _cproj.N_OBS_MEAN
_N_OBS_SIGMA_ORIG = _cproj.N_OBS_SIGMA

try:
    _cproj.N_OBS_MEAN = 3.0
    _cproj.N_OBS_SIGMA = 0.0

    # -- Endpoint mixture at 2100 (matches results_figures.ipynb panel g) --
    mix_n3_mm = _cproj.sample_a4_wais_endpoint(
        200_000, np.random.default_rng(99), rheology_mode=RHEOLOGY_MODE,
    ) * M_TO_MM

    # -- Same n=3 fixed, but with scenario weights changed to 30/70
    #    (P(S1_status_quo)=0.30, P(S2_fast_wais)=0.70) instead of the
    #    baseline 10/90, to see how the weighting alone affects the
    #    smoothness of the low-end of the PDF --
    mix_n3_3070_mm = _cproj.sample_a4_wais_endpoint(
        200_000, np.random.default_rng(99), rheology_mode=RHEOLOGY_MODE,
        scenario_overrides={'weights': {'S1_status_quo': 0.30,
                                        'S2_fast_wais': 0.70}},
    ) * M_TO_MM

    # -- Same n=3 fixed, but with scenario weights changed to 1/99
    #    (P(S1_status_quo)=0.01, P(S2_fast_wais)=0.99) --
    mix_n3_0199_mm = _cproj.sample_a4_wais_endpoint(
        200_000, np.random.default_rng(99), rheology_mode=RHEOLOGY_MODE,
        scenario_overrides={'weights': {'S1_status_quo': 0.01,
                                        'S2_fast_wais': 0.99}},
    ) * M_TO_MM

    # -- Full trajectory (matches this notebook's cell 13 / panel h) --
    wais_n3_m, wais_n3_params = _cproj.sample_a4_wais_trajectories(
        N_SAMPLES, np.random.default_rng(2026), PROJ_YEARS,
        rheology_mode=RHEOLOGY_MODE,
        anchor_year=anchor_year,
        anchor_value_mm=anchor_value_mm,
        anchor_sigma_mm=anchor_sigma_mm,
        obs_years=wais_year,
        obs_values_mm=wais_rebase * M_TO_MM,
        obs_sigmas_mm=wais_sigma * M_TO_MM,
    )
finally:
    _cproj.N_OBS_MEAN = _N_OBS_MEAN_ORIG
    _cproj.N_OBS_SIGMA = _N_OBS_SIGMA_ORIG

# -- Current (published) mixture at 2100, recomputed with identical seed --
mix_current_mm = sample_a4_wais_endpoint(
    200_000, np.random.default_rng(99), rheology_mode=RHEOLOGY_MODE,
) * M_TO_MM

print('Endpoint mixture at 2100:')
print(f'  Current (n~N(4.1,0.4^2)): median={np.median(mix_current_mm):.0f} mm '
      f'[{np.percentile(mix_current_mm,5):.0f}, {np.percentile(mix_current_mm,95):.0f}]')
print(f'  n=3 (fixed):              median={np.median(mix_n3_mm):.0f} mm '
      f'[{np.percentile(mix_n3_mm,5):.0f}, {np.percentile(mix_n3_mm,95):.0f}]')
print(f'  Rheology correction effect on median: '
      f'{(np.median(mix_current_mm)/np.median(mix_n3_mm) - 1)*100:+.1f}%')
print(f'  Rheology correction effect on p95: '
      f'{(np.percentile(mix_current_mm,95)/np.percentile(mix_n3_mm,95) - 1)*100:+.1f}%')

idx_2100_n3 = np.argmin(np.abs(PROJ_YEARS - 2100))
print(f'\nFull trajectory (blended mixture) at 2100:')
print(f'  Current: median={np.median(wais_samples_m[:, idx_2100_n3])*M_TO_MM:.0f} mm')
print(f'  n=3:     median={np.median(wais_n3_m[:, idx_2100_n3])*M_TO_MM:.0f} mm')
print(f'  Rheology correction effect on median: '
      f'{(np.median(wais_samples_m[:, idx_2100_n3])/np.median(wais_n3_m[:, idx_2100_n3]) - 1)*100:+.1f}%')
# Out:
# Endpoint mixture at 2100:
#   Current (n~N(4.1,0.4^2)): median=295 mm [75, 1164]
#   n=3 (fixed):              median=226 mm [75, 885]
#   Rheology correction effect on median: +30.2%
#   Rheology correction effect on p95: +31.5%
#
# Full trajectory (blended mixture) at 2100:
#   Current: median=297 mm
#   n=3:     median=229 mm
#   Rheology correction effect on median: +29.8%

# %%
# ── Comparison figure: current vs. n=3 (fixed) ──
from scipy.stats import gaussian_kde as _kde_n3

fig_n3, (ax_pdf_n3, ax_fan_n3) = plt.subplots(1, 2, figsize=(14, 5.5))

_colors_n3 = {'current': 'tab:blue', 'n3': 'tab:gray', 'n3_3070': 'tab:red',
              'n3_0199': 'tab:purple'}
_labels_n3 = {'current': 'Current (n ~ N(4.1, 0.4\u00b2))',
              'n3': 'n = 3 (fixed, no rheology correction)',
              'n3_3070': 'n = 3 (fixed), 30/70 weighting',
              'n3_0199': 'n = 3 (fixed), 1/99 weighting'}
_no_fill_n3 = {'n3_3070', 'n3_0199'}
_dashed_n3 = {'n3_3070', 'n3_0199'}

# -- Panel (g)-equivalent: endpoint PDF at 2100 --
_x_n3 = np.linspace(0, 3000, 600)
_dx_n3 = _x_n3[1] - _x_n3[0]
for key, samp in [('current', mix_current_mm), ('n3', mix_n3_mm),
                  ('n3_3070', mix_n3_3070_mm), ('n3_0199', mix_n3_0199_mm)]:
    _kde = _kde_n3(samp, bw_method='scott')
    _prob = _kde(_x_n3) * _dx_n3 * 100
    ax_pdf_n3.plot(_prob, _x_n3, lw=2, color=_colors_n3[key], label=_labels_n3[key],
                   ls='--' if key in _dashed_n3 else '-')
    if key not in _no_fill_n3:
        ax_pdf_n3.fill_betweenx(_x_n3, _prob, alpha=0.15, color=_colors_n3[key])
    _med = np.median(samp)
    _prob_at_med = _kde(np.array([_med]))[0] * _dx_n3 * 100
    ax_pdf_n3.plot([0, _prob_at_med], [_med, _med], ls='--', lw=1.2, color=_colors_n3[key])

ax_pdf_n3.set_xlim(0, 2.0)
ax_pdf_n3.set_ylim(0, 3000)
ax_pdf_n3.set_xlabel('Probability (%)')
ax_pdf_n3.set_ylabel('WAIS SLR at 2100 (mm)')
ax_pdf_n3.legend(fontsize=10, loc='upper right')
ax_pdf_n3.grid(True, alpha=0.2)
ax_pdf_n3.set_title('Endpoint mixture at 2100 (cf. Fig. 3g)')
ax_pdf_n3.text(0.02, 0.96, "(g')", transform=ax_pdf_n3.transAxes,
               fontweight='bold', fontsize=14)

# -- Panel (h)-equivalent: projection fan (median, 17-83% CI) --
_proj_mask_n3 = PROJ_YEARS >= 2020
for key, samples_m in [('current', wais_samples_m), ('n3', wais_n3_m)]:
    _med_f = np.median(samples_m, axis=0) * M_TO_MM
    _p17_f = np.percentile(samples_m, 17, axis=0) * M_TO_MM
    _p83_f = np.percentile(samples_m, 83, axis=0) * M_TO_MM
    ax_fan_n3.plot(PROJ_YEARS[_proj_mask_n3], _med_f[_proj_mask_n3],
                   color=_colors_n3[key], lw=2.5, label=_labels_n3[key])
    ax_fan_n3.fill_between(PROJ_YEARS[_proj_mask_n3], _p17_f[_proj_mask_n3], _p83_f[_proj_mask_n3],
                           color=_colors_n3[key], alpha=0.20)

ax_fan_n3.set_xlim(1992, 2100)
ax_fan_n3.set_ylim(bottom=-40)
ax_fan_n3.set_xlabel('Year')
ax_fan_n3.set_ylabel('WAIS SLR (mm)')
ax_fan_n3.legend(fontsize=10, loc='upper left')
ax_fan_n3.grid(True, alpha=0.2)
ax_fan_n3.set_title('Projection fan, median + 17-83% CI (cf. Fig. 3h)')
ax_fan_n3.text(0.02, 0.96, "(h')", transform=ax_fan_n3.transAxes,
               fontweight='bold', fontsize=14)

plt.tight_layout()
plt.savefig(f'{FIG_DIR}/component_wais_rheology_n3_comparison.png', dpi=150, bbox_inches='tight')
plt.show()
print('Saved component_wais_rheology_n3_comparison.png')
# Out:
# Saved component_wais_rheology_n3_comparison.png

# %% [markdown]
# ---
#
# ## References
#
# | Citation | Full reference | DOI |
# |----------|--------------|-----|
# | Bamber et al. (2019) | Bamber, Oppenheimer, Kopp, Aspinall & Cooke. Ice sheet contributions to future sea-level rise from structured expert judgment. *PNAS* 116, 11195--11200. | [10.1073/pnas.1817205116](https://doi.org/10.1073/pnas.1817205116) |
# | Bassis & Walker (2012) | Bassis & Walker. Upper and lower limits on the stability of calving glaciers from the yield strength envelope of ice. *Proc. R. Soc. A* 468, 913--931. | [10.1098/rspa.2011.0422](https://doi.org/10.1098/rspa.2011.0422) |
# | Bons et al. (2018) | Bons et al. Greenland Ice Sheet: Higher nonlinearity of ice flow significantly reduces estimated basal motion. *GRL* 45, 6542--6548. | [10.1029/2018GL078356](https://doi.org/10.1029/2018GL078356) |
# | Clerc et al. (2019) | Clerc, Minchew & Behn. Marine ice cliff instability mitigated by slow removal of ice shelves. *GRL* 46, 12108--12116. | [10.1029/2019GL084183](https://doi.org/10.1029/2019GL084183) |
# | DeConto & Pollard (2016) | DeConto & Pollard. Contribution of Antarctica to past and future sea-level rise. *Nature* 531, 591--597. | [10.1038/nature17145](https://doi.org/10.1038/nature17145) |
# | DeConto et al. (2021) | DeConto et al. The Paris Climate Agreement and future sea-level rise from Antarctica. *Nature* 593, 83--89. | [10.1038/s41586-021-03427-0](https://doi.org/10.1038/s41586-021-03427-0) |
# | Dow et al. (2022) | Dow et al. Antarctic basal environment shaped by high-pressure flow through a subglacial river system. *Nature Geoscience* 15, 892--898. | [10.1038/s41561-022-01059-1](https://doi.org/10.1038/s41561-022-01059-1) |
# | Edwards et al. (2019) | Edwards et al. Revisiting Antarctic ice loss due to marine ice-cliff instability. *Nature* 566, 58--64. | [10.1038/s41586-019-0901-4](https://doi.org/10.1038/s41586-019-0901-4) |
# | Fan et al. (2025) | Fan et al. Flow laws for ice constrained by 70 years of laboratory experiments. *Nature Geoscience* 18, 296--304. | [10.1038/s41561-025-01661-z](https://doi.org/10.1038/s41561-025-01661-z) |
# | Fox-Kemper et al. (2021) | Fox-Kemper et al. Ocean, cryosphere and sea level change. In *IPCC AR6 WGI*, Ch. 9. | [10.1017/9781009157896.011](https://doi.org/10.1017/9781009157896.011) |
# | Getraer & Morlighem (2025) | Getraer & Morlighem. Increasing the Glen-Nye power-law exponent accelerates ice-loss projections for the Amundsen Sea Embayment. *GRL* 52, e2024GL112516. | [10.1029/2024GL112516](https://doi.org/10.1029/2024GL112516) |
# | Goldberg et al. (2026) | Goldberg, Morlighem & Gourmelen. Recent observations of Thwaites Glacier, West Antarctica are consistent with high rates of loss in next 50 years. *GRL* 53, e2025GL118823. | [10.1029/2025GL118823](https://doi.org/10.1029/2025GL118823) |
# | Graham et al. (2022) | Graham et al. Rapid retreat of Thwaites Glacier in the pre-satellite era. *Nature Geoscience* 15, 706--713. | [10.1038/s41561-022-01019-9](https://doi.org/10.1038/s41561-022-01019-9) |
# | Gudmundsson et al. (2012) | Gudmundsson et al. The stability of grounding lines on retrograde slopes. *The Cryosphere* 6, 1497--1505. | [10.5194/tc-6-1497-2012](https://doi.org/10.5194/tc-6-1497-2012) |
# | Haseloff & Sergienko (2018) | Haseloff & Sergienko. The effect of buttressing on grounding line dynamics. *J. Glaciol.* 64, 417--431. | [10.1017/jog.2018.30](https://doi.org/10.1017/jog.2018.30) |
# | Joughin et al. (2014) | Joughin, Smith & Medley. Marine ice sheet collapse potentially under way for the Thwaites Glacier Basin. *Science* 344, 735--738. | [10.1126/science.1249055](https://doi.org/10.1126/science.1249055) |
# | Joughin et al. (2021) | Joughin, Shapero, Dutrieux & Smith. Ocean-induced melt volume directly paces ice loss from Pine Island Glacier. *Science Advances* 7, eabi5738. | [10.1126/sciadv.abi5738](https://doi.org/10.1126/sciadv.abi5738) |
# | Jourdain et al. (2022) | Jourdain et al. Ice shelf basal melt rates in the Amundsen Sea at the end of the 21st century. *GRL* 49, e2022GL100629. | [10.1029/2022GL100629](https://doi.org/10.1029/2022GL100629) |
# | Martin et al. (2026) | Martin, Kachuck, Trevers, Millstein, Cornford & Minchew. Rates of sea-level rise are highly sensitive to ice viscosity parameters in model benchmarks. *AGU Advances* 7(2). | [10.1029/2025AV001946](https://doi.org/10.1029/2025AV001946) |
# | Millstein et al. (2022) | Millstein, Minchew & Pegler. Ice viscosity is more sensitive to stress than commonly assumed. *Commun. Earth Environ.* 3, 57. | [10.1038/s43247-022-00385-x](https://doi.org/10.1038/s43247-022-00385-x) |
# | Morlighem et al. (2020) | Morlighem et al. Deep glacial troughs and stabilizing ridges unveiled beneath the margins of the Antarctic ice sheet. *Nature Geoscience* 13, 132--137. | [10.1038/s41561-019-0510-8](https://doi.org/10.1038/s41561-019-0510-8) |
# | Morlighem et al. (2024) | Morlighem et al. The West Antarctic ice sheet may not be vulnerable to marine ice cliff instability during the 21st century. *Science Advances* 10, eado7794. | [10.1126/sciadv.ado7794](https://doi.org/10.1126/sciadv.ado7794) |
# | Naughten et al. (2023) | Naughten, Holland & De Rydt. Unavoidable future increase in West Antarctic ice-shelf melting over the twenty-first century. *Nature Climate Change* 13, 1222--1228. | [10.1038/s41558-023-01818-x](https://doi.org/10.1038/s41558-023-01818-x) |
# | Otosaka et al. (2023) | Otosaka et al. Mass balance of the Greenland and Antarctic ice sheets from 1992 to 2020. *ESSD* 15, 1597--1616. | [10.5194/essd-15-1597-2023](https://doi.org/10.5194/essd-15-1597-2023) |
# | Pegler (2018) | Pegler. Marine ice sheet dynamics: the impacts of ice-shelf buttressing. *J. Fluid Mech.* 857, 605--647. | [10.1017/jfm.2018.741](https://doi.org/10.1017/jfm.2018.741) |
# | Pfeffer et al. (2008) | Pfeffer, Harper & O'Neel. Kinematic constraints on glacier contributions to 21st-century sea-level rise. *Science* 321, 1340--1343. | [10.1126/science.1159099](https://doi.org/10.1126/science.1159099) |
# | Ranganathan & Minchew (2024) | Ranganathan & Minchew. A modified viscous flow law for natural glacier ice: Scaling from laboratories to ice sheets. *PNAS* 121(23). | [10.1073/pnas.2309788121](https://doi.org/10.1073/pnas.2309788121) |
# | Rignot et al. (2026) | Rignot et al. Thirty years of glacier grounding line retreat in Antarctica. *PNAS* 123(10), e2524380123. | [10.1073/pnas.2524380123](https://doi.org/10.1073/pnas.2524380123) |
# | Robel et al. (2019) | Robel, Seroussi & Roe. Marine ice sheet instability amplifies and skews uncertainty in projections of future sea-level rise. *PNAS* 116, 14887--14892. | [10.1073/pnas.1904822116](https://doi.org/10.1073/pnas.1904822116) |
# | Schlemm et al. (2022) | Schlemm, Feldmann, Winkelmann & Levermann. Stabilizing effect of m\u00e9lange buttressing on the marine ice-cliff instability of the West Antarctic Ice Sheet. *The Cryosphere* 16, 1979--1996. | [10.5194/tc-16-1979-2022](https://doi.org/10.5194/tc-16-1979-2022) |
# | Schoof (2007) | Schoof. Ice sheet grounding line dynamics: Steady states, stability, and hysteresis. *JGR Earth Surface* 112, F03S28. | [10.1029/2006JF000664](https://doi.org/10.1029/2006JF000664) |
# | Schoof (2012) | Schoof. Marine ice sheet stability. *J. Fluid Mech.* 698, 62--72. | [10.1017/jfm.2012.43](https://doi.org/10.1017/jfm.2012.43) |
# | Seroussi et al. (2020) | Seroussi et al. ISMIP6 Antarctica: a multi-model ensemble of the Antarctic ice sheet evolution over the 21st century. *The Cryosphere* 14, 3033--3070. | [10.5194/tc-14-3033-2020](https://doi.org/10.5194/tc-14-3033-2020) |
# | van den Akker et al. (2025) | van den Akker et al. Present-day mass loss rates are a precursor for West Antarctic Ice Sheet collapse. *The Cryosphere* 19, 283--301. | [10.5194/tc-19-283-2025](https://doi.org/10.5194/tc-19-283-2025) |
